# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import requests
from bs4 import BeautifulSoup as BS
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# 测试 - 冰冷之海的主页
url = 'http://space.bilibili.com/742470/#!/video?keyword=&order=senddate&page=1&tid=0'

# %%
# 成功连接
requests.get(url).status_code
# Out:
# 200

# %%
headers = {'Accept-Language':'zh-cn,zh;q=0.8,en-us;q=0.5,en;q=0.3', 
           'User-Agent':'Mozilla/5.0 (Windows NT 6.1; rv:28.0) Gecko/20100101 Firefox/28.0',
           'Connection':'keep-alive'}

# %% [markdown]
# 接下来就像一般的爬数据，不过这次练习用不同的function来实现。需要得到的数据：
# - 视频页列表
# - 视频页
#     - 日期
#     - 播放量、弹幕量、收藏量、分享量、评论量、硬币量、时间、充电量
#     - 标签
#
# 声明：此文本有大量用于探索和练习的代码，并保留大量错误信息用于回顾。我的目标只有一个 - 得到我想要的所有内容，所有优化代码的内容均不在此文本中

# %% [markdown]
# ## 探索

# %% [markdown]
# ### 非function测试

# %%
# get url list
# 1st - get pager
response = requests.get(url, headers=headers)
list_soup = BS(response.content, 'html.parser')
list_soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8">
# <meta content="webkit|ie-comp|ie-stand" name="renderer">
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
# <title>冰冷之海的个人空间 - 哔哩哔哩 ( ゜- ゜)つロ 乾杯~ Bilibili</title>
# <meta content="bilibili是国内知名的视频弹幕网站，这里有最及时的动漫新番，最棒的ACG氛围，最有创意的Up主。大家可以在这里找到许多欢乐。" name="description">
# <meta content="B站,弹幕,字幕,AMV,MAD,MTV,ANIME,动漫,动漫音乐,游戏,游戏解说,ACG,galgame,动画,番组,新番,初音,洛天依,vocaloid" name="keywords">
# <link href="//static.hdslb.com/css/core-v5/base.css" rel="stylesheet">
# <style type="text/css">
#   .space-seo {
#     display: none;
#   }
#
#   .wrapper {
#     width: 1100px;
#     margin: 0 auto;
#     position: relative;
#   }
#
#   #browser-version-tip {
#     position: absolute;
#     display: none;
#     top: 42px;
#     left: 0;
#     z-index: 100;
#     width: 100%;
#     height: 40px;
#     line-height: 40px;
#     background-color: #e40c0c;
#     text-align: center;
#     font-size: 14px;
#     color: #fff;
#   }
#
#   #browser-version-tip a {
#     margin: 0 2px;
#     text-decoration: underline;
#     color: #0077ff;
#   }
#
#   #browser-version-tip #close-browser-tip {
#     position: absolute;
#     right: 0;
#     top: 10px;
#     display: inline-block;
#     margin-left: 15px;
#     width: 20px;
#     height: 20px;
#     background-image: url(//space.bilibili.com/icons2.png);
#     background-position: -1368px -278px;
#     vertical-align: middle;
#   }
#   </style>
# <script type="text/javascript">
#   var _bili_space_mid = 742470;
#   var urlRE = /https?:\/\/space.bilibili.com\/\d+\//g; // //space.bilibili.com/1/
#   var hashRE = /^#!\/.+?/;
#   var url = window.location;
#   var path = url.pathname.replace(/\//g, '');
#   var origin = url.protocol + '//' + url.hostname;
#   var hash = url.hash;
#   var search = url.search;
#
#   var oldUrlReg = {};
#   var params;
#   var newSearch = '';
#   var newUrl = '';
#
#   // 如果路由规则对不上，先改路由
#   if (!urlRE.test(url.href) || path != _bili_space_mid) {
#     newUrl = origin + '/' + _bili_space_mid + '/' + (hashRE.test(hash) ? hash : '#!/');
#     window.location.href = newUrl;
#   } else {
#     // 对老版本做hash值的兼容
#     oldUrlReg.video = /^#!\/video\/(\d+)\/(.*)\/(\d+)/; // tid/keyword/page
#     oldUrlReg.fans = /^#!\/fans\/(.+?)\/(\d+)/; // list/page
#     oldUrlReg.fav = /^#!\/fav\/(\d+)\/(\d+)\/(.*)\/(\d+)/; // fid/tid/keyword/page
#     oldUrlReg.qz = /^#!\/qz-(.+)\/(\d+)/; // tab/page
#     oldUrlReg.channel = /^#!\/channel-detail\/(\d+)\/(\d+)\/(\d+)/; // cid/page/order
#
#     if (oldUrlReg.video.test(hash)) {
#       params = oldUrlReg.video.exec(hash);
#       newSearch = '?tid=' + params[1] + '&keyword=' + params[2] + '&page=' + params[3];
#       newUrl = origin + '/' + _bili_space_mid + '/#!/video' + newSearch;
#       window.location.href = newUrl;
#     } else if (oldUrlReg.fans.test(hash)) {
#       params = oldUrlReg.fans.exec(hash);
#       newSearch = '?page=' + params[2];
#       newUrl = origin + '/' + _bili_space_mid + '/#!/fans/' + params[1] + newSearch;
#       window.location.href = newUrl;
#     } else if (oldUrlReg.fav.test(hash)) {
#       params = oldUrlReg.fav.exec(hash);
#       newSearch = '?fid=' + params[1] + '&tid=' + params[2] + '&keyword=' + params[3] + '&page=' + params[4];
#       newUrl = origin + '/' + _bili_space_mid + '/#!/fav' + newSearch;
#       window.location.href = newUrl;
#     } else if (oldUrlReg.qz.test(hash)) {
#       params = oldUrlReg.qz.exec(hash);
#       newSearch = '?page=' + params[2];
#       newUrl = origin + '/' + _bili_space_mid + '/#!/qz-' + params[1] + newSearch;
#       window.location.href = newUrl;
#     } else if (oldUrlReg.channel.test(hash)) {
#       params = oldUrlReg.channel.exec(hash);
#       newSearch = '?cid=' + params[1] + '&page=' + params[2] + '&order=' + params[3];
#       newUrl = origin + '/' + _bili_space_mid + '/#!/channel/detail' + newSearch;
#       window.location.href = newUrl;
#     }
#   }
#   </script>
# <link href="//s3.hdslb.com/bfs/static/space/app_e8871dd3.css" rel="stylesheet"/></link></meta></meta></meta></meta></meta></head>
# <body>
# <h1 class="space-seo space-meta">冰冷之海的个人空间。</h1>
# <p class="space-seo space-meta">你可以在这里找到冰冷之海的最新投稿、收藏和订阅。点击关注随时获取冰冷之海的最新动态！</p>
# <div class="z_top_container">
# <div class="z_top">
# <div class="z_header">
# <div class="z_top_nav">
# <ul>
# <li class="home">
# <a class="i-link" href="//www.bilibili.com/"><span>主站</span></a>
# </li>
# <li class="hbili"><a class="i-link" href="http://h.bilibili.com/" title="画友">画友</a></li>
# <li class="b-gc" hasframe="true">
# <a class="i-link" href="//game.bilibili.com/" title="游戏中心">游戏中心</a>
# <div class="i_div game" data-frame="game"></div>
# </li>
# <li class="live" hasframe="true">
# <a class="i-link" href="//live.bilibili.com" target="_blank" title="直播">直播</a>
# <div class="i_div stream" data-frame="stream"></div>
# </li>
# <li class="b-zb"><a class="i-link" href="//bmall.bilibili.com/#!/" target="_blank" title="周边">周边</a></li>
# <li class="b-ml" style="display:none"><a class="i-link" href="//bml.bilibili.com/index2016/?nav" target="_blank" title="BML">BML</a></li>
# <li class="shouji">
# <a class="i-link" href="//app.bilibili.com" target="_blank" title="移动端">移动端</a>
# <div class="mobile-p-box"><div class="mobile-p-qrcode"></div></div>
# </li>
# </ul>
# </div>
# <div class="uns_box">
# <ul class="menu">
# <li class="u-i i_user" guest="no" i_menu="#i_menu_profile" id="i_menu_profile_btn">
# <a class="i-link" href="//space.bilibili.com/" target="_blank">
# <img class="i_face">
# </img></a>
# <div class="i_menu" id="i_menu_profile">
# <div class="i_menu_bg_t"></div>
# <div class="info clearfix"><div class="uname"></div><div class="coin"></div></div>
# <div class="member-menu-wrp">
# <ul class="member-menu">
# <li><a class="account" href="https://account.bilibili.com/site/home" target="_blank"><i class="b-icon b-icon-p-account"></i>个人中心</a></li>
# <li><a class="member" href="http://member.bilibili.com/v/#!/article" target="_blank"><i class="b-icon b-icon-p-member"></i>投稿管理</a></li>
# <li><a class="wallet" href="https://pay.bilibili.com/" target="_blank"><i class="b-icon b-icon-p-wallet"></i>B币钱包</a></li>
# <li><a class="live" href="//live.bilibili.com/i" target="_blank"><i class="b-icon b-icon-p-live"></i>直播中心</a></li>
# </ul>
# </div>
# <div class="member-bottom">
# <a class="logout" href="https://account.bilibili.com/login?act=exit">退出</a>
# </div>
# </div>
# </li>
# <li class="u-i" guest="no" i_menu="become_vip" id="i_menu_become_vip">
# <a class="i-link" href="//big.bilibili.com/site/big.html" target="_blank">成为大会员</a>
# </li>
# <li class="u-i" guest="no" i_menu="community_msg" id="i_menu_community_msg_btn">
# <a class="i-link" href="//message.bilibili.com" target="_blank">消息</a>
# </li>
# <li class="u-i" guest="no" i_menu="#dyn_wnd" id="i_menu_msg_btn">
# <div class="num" id="dynamic_num_total"></div>
# <a class="i-link" href="//www.bilibili.com/account/dynamic" target="_blank">动态</a>
# </li>
# <li class="u-i" guest="no" i_menu="#i_menu_fav" id="i_menu_fav_btn">
# <a class="i-link" href="//space.bilibili.com/#!/favlist" target="_blank">收藏夹</a>
# </li>
# <li class="u-i" guest="no" id="i_menu_history_btn">
# <a class="i-link" href="//www.bilibili.com/account/history">历史</a>
# </li>
# <li class="u-i" guest="yes" id="i_menu_login_reg">
# <a class="i-link login" href="https://account.bilibili.com/login" id="i_menu_login_btn"><span>登录</span></a><i class="s-line"></i><a class="i-link reg" href="https://www.bilibili.com/register" id="i_menu_register_btn"><span>注册</span></a>
# </li>
# <li class="u-i b-post">
# <a class="i-link" href="http://member.bilibili.com/v/video/submit.html" target="_blank">投 稿</a>
# <ul class="s-menu">
# <li><a href="http://member.bilibili.com/v/video/submit.html" target="_blank"><i class="b-icon b-icon-vp"></i><em>视频投稿</em></a></li>
# <li><a href="http://member.bilibili.com/v/#!/article" target="_blank"><i class="b-icon b-icon-vm"></i><em>投稿管理</em></a></li>
# <li><a href="http://member.bilibili.com/v/" target="_blank"><i class="b-icon b-icon-vc"></i><em>创作中心</em></a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div id="browser-version-tip">
# <div class="wrapper">
#       抱歉，您正在使用不支持的浏览器访问个人空间。推荐您<a href="//www.google.cn/chrome/browser/desktop/index.html">安装 Chrome 浏览器</a>以获得更好的体验 ヾ(o◕∀◕)ﾉ<a href="javascript:;" id="close-browser-tip"></a>
# </div>
# </div>
# <div id="space-body"></div>
# <script type="text/javascript">
#   // IE9及以下不支持，IE9也提示升级到chrome
#   var isIE = function(ver) {
#     var b = document.createElement('b');
#     b.innerHTML = '<!--[if IE ' + ver + ']><i></i><![endif]-->';
#     return b.getElementsByTagName('i').length === 1;
#   }
#   var $BVcloseBtn = document.getElementById('close-browser-tip');
#   var $BVtip = document.getElementById('browser-version-tip');
#   if (isIE(9) || isIE(8) || isIE(7) || isIE(6)) {
#     $BVtip.style.display = 'block';
#     $BVcloseBtn.onclick = function() {
#       $BVtip.style.display = 'none';
#     }
#   }
#   </script>
# <script src="//s3.hdslb.com/bfs/static/space/vendor_e8871dd3.js" type="text/javascript"></script><script src="//s3.hdslb.com/bfs/static/space/app_e8871dd3.js" type="text/javascript"></script></body>
# </html>

# %% [markdown]
# 我天真了，事实证明，根本不需要这样生爬。bilibili有很好的metadata，只需要找到相应的地址就可以得到完整的json file。
#
# 经过搜索与实验，得出以下步骤：
# - 进入移动版的其视频页，本例为：http://space.bilibili.com/742470/mobile/video
# - 开发者工具 -> Network -> XHR -> 得到获得视频信息的URL为：http://space.bilibili.com/ajax/member/getSubmitVideos?pagesize=8&page=2&mid=742470&pid=NaN&_=1489370576492
# - _（取消md的italic）经过测试，我们可以删掉一些不需要的字段，仅仅需要page和mid：http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=742470
# - 然而我们发现created并没有具体时间，我们还需要访问具体页面爬到时间
# - ok，那首先得到所有aid，放入一个list，并以aid为名所dict

# %%
import json

# %%
# 都是bytes，decode('utf-8')没用，头疼..
url = 'http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=742470'
requests.get(url).content
# Out:
# b'{"status":true,"data":{"vlist":[{"aid":9137695,"copyright":"Original","typeid":65,"title":"\\u51b0\\u51b7\\u89e3\\u8bf4\\uff1a\\u201c\\u8352\\u7af9\\u53cd\\u51fb\\u6d41\\u201d\\u5355\\u4eba\\u6597\\u6280\\u5b9e\\u51b5\\uff08\\u6392\\u540d50-20\\uff09","subtitle":"","play":21441,"review":228,"video_review":819,"favorites":223,"mid":742470,"author":"","description":"\\u7af9\\u5b50\\u914d\\u8352\\uff0c\\u5929\\u4e0b\\u65e0\\u53cc\\uff01\\n6\\u661f\\u8352\\u5fa1\\u9b42\\u5c5e\\u6027\\u65b9\\u9762\\u4ee5\\u540e\\u4f1a\\u4f18\\u5316\\uff0c\\u4e0d\\u6392\\u9664\\u4ee5\\u540e\\u6362\\u9b4d\\u9b49\\u4e4b\\u7c7b\\u63a7\\u5236\\u5fa1\\u9b42\\u7684\\u53ef\\u80fd\\uff0c\\u4f46\\u662f\\u8fd8\\u9700\\u8981\\u8fdb\\u4e00\\u6b65\\u6d4b\\u8bd5\\u3002\\n\\u53e6\\u5916\\u7af9\\u5b50\\u3001\\u6912\\u56fe\\u3001\\u96e8\\u5973\\u90fd\\u9700\\u8981\\u53476\\u661f\\u3002\\u8be5\\u9635\\u5bb9\\u5982\\u679c\\u9700\\u8981\\u673a\\u52a8\\u6838\\u5fc3\\uff0c\\u9570\\u9f2c\\u4e5f\\u662f\\u4e2a\\u4e0d\\u9519\\u7684\\u9009\\u62e9\\u3002\\n\\u65b0\\u6d6a\\u5fae\\u535a\\uff1a@\\u51b0\\u51b7\\u4e4b\\u6d77\\u89e3\\u8bf4\\n\\u7c89\\u4e1d\\u7fa4\\uff1a\\n1\\u7fa4\\uff1a121951577\\n2\\u7fa4\\uff1a143191644\\n3\\u7fa4\\uff1a10825535\\n4\\u7fa4\\uff1a49057308\\n5\\u7fa4\\uff1a175953348\\n6\\u7fa4\\uff1a583401101\\n\\uff08\\u867d\\u71366\\u7fa4\\u9a6c\\u4e0a\\u6ee1\\u4e86\\uff0c\\u4f46\\u662f\\u6682\\u65f6\\u4e0d\\u6253\\u7b97\\u5f00\\u65b0\\u7fa4\\uff0c\\u56e0\\u4e3a1-5\\u7fa4\\u73b0\\u5728\\u6709\\u5f88\\u591a\\u7a7a\\u4f4d\\uff09 \\u200b\\u200b\\u200b\\u200b","created":1489375048,"pic":"http:\\/\\/i0.hdslb.com\\/bfs\\/archive\\/46ac899c49fb7e7ede627db415c112df1a4fe89f.jpg","comment":819,"length":"64:48","hide_click":false},{"aid":9122374,"copyright":"Original","typeid":65,"title":"\\u51b0\\u51b7\\u89e3\\u8bf4\\uff1a\\u201c\\u8352\\u7af9\\u53cd\\u51fb\\u6d41\\u201d\\u534f\\u540c\\u6597\\u6280\\u9996\\u79c0","subtitle":"","play":12854,"review":119,"video_review":451,"favorites":106,"mid":742470,"author":"","description":"\\u6211\\u4eec\\u7684\\u53e3\\u53f7\\u662f\\u201c\\u7af9\\u5b50\\u914d\\u8352\\uff0c\\u5929\\u4e0b\\u65e0\\u53cc\\uff01\\u201d\\n\\u7136\\u540e\\u534f\\u540c\\u5404\\u79cd\\u88ab\\u540a\\u6253\\uff0c\\u6253\\u4e0d\\u5e26\\u63a7\\u7684\\u901f\\u63a7\\u8fd8\\u51d1\\u5408\\u2026\\u2026\\n\\u800c\\u534f\\u540c\\u6597\\u6280\\u6548\\u679c\\u4e0d\\u597d\\uff0c\\u592a\\u6015\\u8fd4\\u9b42\\u9999\\u548c\\u5175\\u52c7\\u4e86\\u3002\\u800c\\u4e14\\u6ca1\\u6709\\u529e\\u6cd5\\u7528\\u6674\\u660e\\u548c\\u5996\\u7434\\u5e08\\u3002\\n\\u665a\\u4e0a\\u6211\\u6597\\u6280\\u518d\\u8bd5\\u8bd5\\uff0c\\u6211\\u81ea\\u5df1\\u7684\\u6912\\u56fe\\u4e5f5\\u661f\\u4e86\\u3002o(\\u2229_\\u2229)o \\n\\u76f4\\u64ad\\u5730\\u5740\\uff1ahttp:\\/\\/cc.163.com\\/510477\\uff08\\u6bcf\\u665a7\\u70b9-11\\u70b9\\uff09","created":1489373824,"pic":"http:\\/\\/i0.hdslb.com\\/bfs\\/archive\\/d94465ffa617bc85c71357378081d126ec1c7952.jpg","comment":451,"length":"92:58","hide_click":false},{"aid":9109711,"copyright":"Original","typeid":65,"title":"\\u3010\\u9634\\u9633\\u5e08\\u3011\\u9488\\u5973\\u8352VS\\u77f3\\u8e1e\\/\\u5e74\\u517d+\\u4e07\\u5e74\\u7af9\\u5168\\u4f20\\u8bb0\\uff01","subtitle":"","play":92013,"review":737,"video_review":804,"favorites":955,"mid":742470,"author":"","description":"\\u8fd9\\u4fe9\\u89c6\\u9891\\u6ca1\\u4ec0\\u4e48\\u5173\\u8054\\uff0c\\u4e0d\\u8fc7\\u90fd\\u6bd4\\u8f83\\u77ed\\uff0c\\u5c31\\u653e\\u4e00\\u8d77\\u5427\\u3002\\u8865\\u5145\\u8bf4\\u660e\\uff1a\\n\\u6211\\u7684\\u83528000\\u653b\\u3001\\u6ee1\\u66b4\\u51fb\\u3001\\u57fa\\u7840150%\\u7206\\u4f24\\uff0c\\u57fa\\u672c\\u6ca1\\u901f\\u5ea6\\u3002\\u5e94\\u8be5\\u7b97\\u662f\\u6bd4\\u8f83\\u5e73\\u6c11\\u7684\\u5c5e\\u6027\\u4e86\\u3002\\n\\u8352\\u7684\\u4f20\\u8bb0\\u4e8c\\u3001\\u4e09\\u5df2\\u7ecf\\u89e3\\u9501\\u3002\\u4f46\\u662f\\u4f20\\u8bb0\\u4e00\\u8981\\u6597\\u6280\\u80dc\\u522950\\u6b21\\uff0c\\u7b49\\u90fd\\u89e3\\u9501\\u4e86\\u4e00\\u8d77\\u53d1\\u5427\\u3002\\n\\u53e6\\u5916\\u4e0 ...

# %%
# 好吧，不需要解码
"\u51b0\u51b7\u89e3\u8bf4\uff1a\u9634\u9633\u5e08\u5168\u5f0f\u795e\u4ecb\u7ecd\u4e4b\u96ea\u5973"
# Out:
# '冰冷解说：阴阳师全式神介绍之雪女'

# %%
# 看来需要用re了
requests.get(url).content[80:240]
# Out:
# b'5,"title":"\\u51b0\\u51b7\\u89e3\\u8bf4\\uff1a\\u201c\\u8352\\u7af9\\u53cd\\u51fb\\u6d41\\u201d\\u5355\\u4eba\\u6597\\u6280\\u5b9e\\u51b5\\uff08\\u6392\\u540d50-20\\uff09","subtitle"'

# %%
"\u51b0\\u51b7\\u89e3\\u8bf4\\uff1a\\u201c\\u8352\\u7af9\\u53cd\\u51fb\\u6d41\\u201d\\u5355\\u4eba\\u6597\\u6280\\u5b9e\\u51b5\\uff08\\u6392\\u540d50-20\\uff09"
# Out:
# '冰\\u51b7\\u89e3\\u8bf4\\uff1a\\u201c\\u8352\\u7af9\\u53cd\\u51fb\\u6d41\\u201d\\u5355\\u4eba\\u6597\\u6280\\u5b9e\\u51b5\\uff08\\u6392\\u540d50-20\\uff09'

# %%
str(requests.get(url).content).decode('string_escape')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-f28c823722b8> in <module>()
# ----> 1 str(requests.get(url).content).decode('string_escape')
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
# 尝试codecs
import codecs
codecs.decode('\\u51b7\\u89e3\\u8bf4\\uff1a\\u201c\\u8352\\u7af9\\u53cd\\u51fb\\u6d41\\u201d\\u5355\\u4eba\\u6597\\u6280\\u5b9e\\u51b5\\uff08\\u6392\\u540d50-20\\uff09', 'unicode_escape')
# Out:
# '冷解说：“荒竹反击流”单人斗技实况（排名50-20）'

# %%
type('\\u51b7\\u89e3\\u8bf4\\uff1a\\u201c\\u8352\\u7af9\\u53cd\\u51fb\\u6d41\\u201d\\u5355\\u4eba\\u6597\\u6280\\u5b9e\\u51b5\\uff08\\u6392\\u540d50-20\\uff09')
# Out:
# str

# %%
# 终于... 通过使用codecs的 .decode(xxx, 'unicode_escape')
testre = codecs.decode(requests.get(url).content, 'unicode_escape')
testre
# Out:
# '{"status":true,"data":{"vlist":[{"aid":9137695,"copyright":"Original","typeid":65,"title":"冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）","subtitle":"","play":21441,"review":228,"video_review":819,"favorites":223,"mid":742470,"author":"","description":"竹子配荒，天下无双！\n6星荒御魂属性方面以后会优化，不排除以后换魍魉之类控制御魂的可能，但是还需要进一步测试。\n另外竹子、椒图、雨女都需要升6星。该阵容如果需要机动核心，镰鼬也是个不错的选择。\n新浪微博：@冰冷之海解说\n粉丝群：\n1群：121951577\n2群：143191644\n3群：10825535\n4群：49057308\n5群：175953348\n6群：583401101\n（虽然6群马上满了，但是暂时不打算开新群，因为1-5群现在有很多空位） \u200b\u200b\u200b\u200b","created":1489375048,"pic":"http:\\/\\/i0.hdslb.com\\/bfs\\/archive\\/46ac899c49fb7e7ede627db415c112df1a4fe89f.jpg","comment":819,"length":"64:48","hide_click":false},{"aid":9122374,"copyright":"Original","typeid":65,"title":"冰冷解说：“荒竹反击流”协同斗技首秀","subtitle":"","play":12854,"review":119,"video_review":451,"favorites":106,"mid":742470,"author":"","description":"我们的口号是“竹子配荒，天下无双！”\n然后协同各种被吊打，打不带控的速控还凑合……\n而协同斗技效果不好，太怕返魂香和兵勇了。而且没有办法用晴明和妖琴师。\n晚上我斗技再试试，我自己的椒图也5星了。o(∩_∩)o \n直播地址：http:\\/\\/cc.163.com\\/510477（每晚7点-11点）","created":1489373824,"pic":"http:\\/\\/i0.hdslb.com\\/bfs\\/archive\\/d94465ffa617bc85c71357378081d126ec1c7952.jpg","comment":451,"length":"92:58","hide_click":false},{"aid":9109711,"copyright":"Original","typeid":65,"title":"【阴阳师】针女荒VS石踞\\/年兽+万年竹全传记！","subtitle":"","play":92013,"review":737,"video_review":804,"favorites":955,"mid":742470,"author":"","description":"这俩视频没什么关联，不过都比较短，就放一起吧。补充说明：\n我的荒8000攻、满暴击、基础150%爆伤，基本没速度。应该算是比较平民的属性了。\n荒的传记二、三已经解锁。但是传记一要斗技胜利50次，等都解锁了一起发吧。\n另外万年竹传记二解锁会给一个黑蛋~\n微博：@冰冷之海解说。","created":1489261292,"pic":"http:\\/\\/i0.hdslb.com\\/bfs\\/archive\\/727c2aec41f01ecf05b3797816e2747fc62c3e6b.jpg","comment":804,"length":"07:21","hide_click":false},{"aid":9071355,"copyright":"Original","typeid":65,"title":"【体验服快报】第005期：荒\\/万年竹\\/新版荒川\\/樱花妖等","subtitle":"","play":55906,"review":846,"video_review":3019,"favorites":482,"mid":742470,"author":"","description":"视频内容依次是：黄金抽狗手、万年竹技能测试、荒技能初窥、新版荒川技能测试、新版樱花妖技能测试、二口女\\/骨女加强数据。片尾广告。\n——————————————————\n已有六星荒川~\n直播地址：http:\\/\\/cc.163.com\\/510477\n直播时间：19：00~22：00","created":1489126868,"pic":"http:\\/\\/i0.hdslb.com\\/bfs\\/archive\\/7f8252963680da930b14906d462578be87600e24.png","comment":3019,"length":"41:55","hide_click":false},{"aid":9047855,"copyright":"Original","typeid":65,"title":"冰冷解说：妇女节特辑！全女式神斗技实况（孟婆、烟烟罗等）","subtitle":"","play":22153,"review":148,"video_review":603,"favorites":143,"mid":742470,"author":"","description":"祝所有的女观众节日快乐！虽然晚了点，但我是爱你们的！\n上传之前我看了一下，这期应该没有音画不同步的问题了。\n每天直播时间：\n中午12：00~13：00\n下午19：00~22：00\n新浪微博：@冰冷之海解说","created":1488996746,"pic":"http:\\/\\/i0.hdslb.com\\/bfs\\/archive\\/49664972ccdbf8400e37c13d009527985fbbc803.jpg","comment":603,"length":"70:00","hide_click":false},{"aid":9014983,"copyright":"Original","typeid":65,"title":"冰冷解说：阴阳师视频攻略031 椒图反击流之酒吞队","subtitle":"","play":27721,"review":308,"video_review":914,"favorites":425,"mid":742470,"author":"","description":"新浪微博：@冰冷之海解说\n文档下载QQ： 583401101","created":1488836356,"pic":"http:\\/\\/i0.hdslb.com\\/bfs\\/archive\\/db51d4956ebff9b559ef53dc416f4aff3a00ecbc.jpg","comment":914,"length":"109:19","hide_click":false},{"aid":8941842,"copyright":"Original","typeid":65,"title":"冰冷解说：阴阳师黑科技005 万箭穿心流","subtitle":"","play":51900,"review":271,"video_review":1042,"favorites":451,"mid":742470,"author":"","description":"妖琴师全式神视频中提到过这种玩法。但是由于妖琴师互相拉几乎不可能无限，所以先手万箭穿心流不太现实。后手的话效果还是不错的。视频不算太长，但也有1个小时，所以建议有时间的时候再看，先收藏+投硬币吧，么么哒！\n新浪微博：@冰冷之海解说\n公众微信：hggyxbd\n","created":1488540670,"pic":"http:\\/\\/i0.hdslb.com\\/bfs\\/archive\\/6b8a2d8878a0a65f78db51fb9d1428f4abb38442.png","comment":1042,"length":"60:26","hide_click":false},{"aid":8850760,"copyright":"Original","typeid":65,"title":"冰冷解说：体验服六星河童斗技首秀o(∩_∩)o","subtitle":"","play":56255,"review":281,"video_review":1167,"favorites":230,"mid":742470,"author":"","description":"技能是111，御魂是硬着头皮凑的。阵容也不太对劲，所以千万别直接套用~\n新浪微博：@冰冷之海解说\nQQ群： 583401101","created":1488105001,"pic":"http:\\/\\/i0.hdslb.com\\/bfs\\/archive\\/25e9ee46454e33d4ea952de1b35750c5beb74005.png","comment": ...

# %%
import re

# %%
m = re.search(r'title', testre)
m.groups()
# Out:
# ()

# %%
len(testre)
# Out:
# 9640

# %%
# 好吧 要用findall
print(re.findall('新浪',testre))
# Out:
# ['新浪', '新浪', '新浪', '新浪', '新浪', '新浪', '新浪', '新浪', '新浪', '新浪', '新浪', '新浪', '新浪', '新浪']

# %%
re.findall('title":"(.*)","sub', testre)
# Out:
# ['冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）',
#  '冰冷解说：“荒竹反击流”协同斗技首秀',
#  '【阴阳师】针女荒VS石踞\\/年兽+万年竹全传记！',
#  '【体验服快报】第005期：荒\\/万年竹\\/新版荒川\\/樱花妖等',
#  '冰冷解说：妇女节特辑！全女式神斗技实况（孟婆、烟烟罗等）',
#  '冰冷解说：阴阳师视频攻略031 椒图反击流之酒吞队',
#  '冰冷解说：阴阳师黑科技005 万箭穿心流',
#  '冰冷解说：体验服六星河童斗技首秀o(∩_∩)o',
#  '【体验服快报】第004期：河畔童谣副本通关实况',
#  '冰冷解说：“三琴余音流”斗技实况教学',
#  '冰冷解说：阴阳师全式神介绍之孟婆',
#  '冰冷解说：阴阳师全式神介绍之雨女',
#  '【体验服快报】第003期：卖御魂\\/古笼火加强\\/雨女加强\\/魅妖加强',
#  '【FGO】萌新100抽测试一下血统！","subtitle":"","play":27149,"review":591,"video_review":690,"favorites":42,"mid":742470,"author":"","description":"有没有老司机给我讲讲，我抽的这些东西厉不厉害？","created":1487231913,"pic":"http:\\/\\/i0.hdslb.com\\/bfs\\/archive\\/36426d548f42d692b1bc914b64d22839db43335c.jpg","comment":690,"length":"07:37","hide_click":false},{"aid":8627224,"copyright":"Original","typeid":65,"title":"冰冷解说：阴阳师全式神介绍之雪女',
#  '冰冷解说：阴阳师全式神介绍之妖琴师',
#  '冰冷解说：后手肉控流大战般若速控队（六星管狐+烟烟罗）',
#  '冰冷解说：阴阳师全式神介绍之烟烟罗',
#  '冰冷解说：阴阳师视频攻略030 鸡肋御魂变废为宝',
#  '冰冷解说：阴阳师全式神介绍之黑童子']

# %%
len(re.findall('title":"(.*)","sub', testre))
# Out:
# 19

# %%
"（）" == "()"
# Out:
# False

# %%
"o(∩_∩)o"
# Out:
# 'o(∩_∩)o'

# %%
"∩" == "n"
# Out:
# False

# %%
'-' == '-'
# Out:
# True

# %%
# 终于，设一个范围
re.findall('title":"(.{1,50})","sub', testre)
# Out:
# ['冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）',
#  '冰冷解说：“荒竹反击流”协同斗技首秀',
#  '【阴阳师】针女荒VS石踞\\/年兽+万年竹全传记！',
#  '【体验服快报】第005期：荒\\/万年竹\\/新版荒川\\/樱花妖等',
#  '冰冷解说：妇女节特辑！全女式神斗技实况（孟婆、烟烟罗等）',
#  '冰冷解说：阴阳师视频攻略031 椒图反击流之酒吞队',
#  '冰冷解说：阴阳师黑科技005 万箭穿心流',
#  '冰冷解说：体验服六星河童斗技首秀o(∩_∩)o',
#  '【体验服快报】第004期：河畔童谣副本通关实况',
#  '冰冷解说：“三琴余音流”斗技实况教学',
#  '冰冷解说：阴阳师全式神介绍之孟婆',
#  '冰冷解说：阴阳师全式神介绍之雨女',
#  '【体验服快报】第003期：卖御魂\\/古笼火加强\\/雨女加强\\/魅妖加强',
#  '【FGO】萌新100抽测试一下血统！',
#  '冰冷解说：阴阳师全式神介绍之雪女',
#  '冰冷解说：阴阳师全式神介绍之妖琴师',
#  '冰冷解说：后手肉控流大战般若速控队（六星管狐+烟烟罗）',
#  '冰冷解说：阴阳师全式神介绍之烟烟罗',
#  '冰冷解说：阴阳师视频攻略030 鸡肋御魂变废为宝',
#  '冰冷解说：阴阳师全式神介绍之黑童子']

# %%
# 如果在 findall 里加入两个或两个以上的()，返回的是一个list里的多个不可更改的 tuple
print(re.findall('title":"(.{1,50})","(sub)', testre),'\n')
print(re.findall('title":"(.{1,50})","(sub)', testre)[0],'\n')
print(re.findall('title":"(.{1,50})","(sub)', testre)[0][1])
# Out:
# [('冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）', 'sub'), ('冰冷解说：“荒竹反击流”协同斗技首秀', 'sub'), ('【阴阳师】针女荒VS石踞\\/年兽+万年竹全传记！', 'sub'), ('【体验服快报】第005期：荒\\/万年竹\\/新版荒川\\/樱花妖等', 'sub'), ('冰冷解说：妇女节特辑！全女式神斗技实况（孟婆、烟烟罗等）', 'sub'), ('冰冷解说：阴阳师视频攻略031 椒图反击流之酒吞队', 'sub'), ('冰冷解说：阴阳师黑科技005 万箭穿心流', 'sub'), ('冰冷解说：体验服六星河童斗技首秀o(∩_∩)o', 'sub'), ('【体验服快报】第004期：河畔童谣副本通关实况', 'sub'), ('冰冷解说：“三琴余音流”斗技实况教学', 'sub'), ('冰冷解说：阴阳师全式神介绍之孟婆', 'sub'), ('冰冷解说：阴阳师全式神介绍之雨女', 'sub'), ('【体验服快报】第003期：卖御魂\\/古笼火加强\\/雨女加强\\/魅妖加强', 'sub'), ('【FGO】萌新100抽测试一下血统！', 'sub'), ('冰冷解说：阴阳师全式神介绍之雪女', 'sub'), ('冰冷解说：阴阳师全式神介绍之妖琴师', 'sub'), ('冰冷解说：后手肉控流大战般若速控队（六星管狐+烟烟罗）', 'sub'), ('冰冷解说：阴阳师全式神介绍之烟烟罗', 'sub'), ('冰冷解说：阴阳师视频攻略030 鸡肋御魂变废为宝', 'sub'), ('冰冷解说：阴阳师全式神介绍之黑童子', 'sub')]
#
# ('冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）', 'sub')
#
# sub

# %% [markdown]
# ## 新三个爬虫设计
#
# 我们争取一次爬取一个 aid 的所有需要信息。
#
# 爬取信息（可在以上地址得到的）:
#     - aid
#     - title
#     - play = view
#     - review = reply
#     - video_review = danmaku - 弹幕
#     - favorites
#     - comment
#     - length
# 爬取信息（在http://api.bilibili.com/archive_stat/stat?aid=? 只需添加aid得到的）：
#     - coin
# 爬取信息（在视频页上得到的）：
#     - 视频地址
#     - 发布时间

# %% [markdown]
# ### 爬取信息一：spider1

# %%
# 最长的 description 大概231
len( "竹子配荒，天下无双！\n6星荒御魂属性方面以后会优化，不排除以后换魍魉之类控制御魂的可能，但是还需要进一步测试。\n另外竹子、椒图、雨女都需要升6星。该阵容如果需要机动核心，镰鼬也是个不错的选择。\n新浪微博：@冰冷之海解说\n粉丝群：\n1群：121951577\n2群：143191644\n3群：10825535\n4群：49057308\n5群：175953348\n6群：583401101\n（虽然6群马上满了，但是暂时不打算开新群，因为1-5群现在有很多空位） ​​​​")
# Out:
# 231

# %%
# description 太长，干扰我们爬取信息，这里分成两部分：description之前和之后
# description 之前
re.findall('aid":(\d+).{1,50}title":"(.{1,50})","sub.{1,50}play":(\d+),"review":(\d+),"video_review":(\d+),"favorites":(\d+)', testre)
# Out:
# [('9137695', '冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）', '21441', '228', '819', '223'),
#  ('9122374', '冰冷解说：“荒竹反击流”协同斗技首秀', '12854', '119', '451', '106'),
#  ('9109711', '【阴阳师】针女荒VS石踞\\/年兽+万年竹全传记！', '92013', '737', '804', '955'),
#  ('9071355',
#   '【体验服快报】第005期：荒\\/万年竹\\/新版荒川\\/樱花妖等',
#   '55906',
#   '846',
#   '3019',
#   '482'),
#  ('9047855', '冰冷解说：妇女节特辑！全女式神斗技实况（孟婆、烟烟罗等）', '22153', '148', '603', '143'),
#  ('9014983', '冰冷解说：阴阳师视频攻略031 椒图反击流之酒吞队', '27721', '308', '914', '425'),
#  ('8941842', '冰冷解说：阴阳师黑科技005 万箭穿心流', '51900', '271', '1042', '451'),
#  ('8850760', '冰冷解说：体验服六星河童斗技首秀o(∩_∩)o', '56255', '281', '1167', '230'),
#  ('8803411', '【体验服快报】第004期：河畔童谣副本通关实况', '39754', '336', '1699', '206'),
#  ('8778401', '冰冷解说：“三琴余音流”斗技实况教学', '45858', '429', '1649', '504'),
#  ('8749188', '冰冷解说：阴阳师全式神介绍之孟婆', '15719', '250', '241', '124'),
#  ('8688869', '冰冷解说：阴阳师全式神介绍之雨女', '21417', '308', '439', '167'),
#  ('8665552',
#   '【体验服快报】第003期：卖御魂\\/古笼火加强\\/雨女加强\\/魅妖加强',
#   '51831',
#   '379',
#   '1665',
#   '258'),
#  ('8648632', '【FGO】萌新100抽测试一下血统！', '27149', '591', '690', '42'),
#  ('8627224', '冰冷解说：阴阳师全式神介绍之雪女', '30829', '531', '715', '403'),
#  ('8569924', '冰冷解说：阴阳师全式神介绍之妖琴师', '36168', '391', '795', '676'),
#  ('8528436', '冰冷解说：后手肉控流大战般若速控队（六星管狐+烟烟罗）', '52319', '335', '1266', '292'),
#  ('8450714', '冰冷解说：阴阳师全式神介绍之烟烟罗', '57091', '311', '554', '480'),
#  ('8325651', '冰冷解说：阴阳师视频攻略030 鸡肋御魂变废为宝', '110669', '1014', '3020', '4673'),
#  ('8164993', '冰冷解说：阴阳师全式神介绍之黑童子', '80315', '443', '1054', '1092')]

# %%
# description 之后
re.findall('comment":(\d+),"length":"([\d:]+)', testre)
# Out:
# [('819', '64:48'),
#  ('451', '92:58'),
#  ('804', '07:21'),
#  ('3019', '41:55'),
#  ('603', '70:00'),
#  ('914', '109:19'),
#  ('1042', '60:26'),
#  ('1167', '71:15'),
#  ('1699', '54:57'),
#  ('1649', '89:02'),
#  ('241', '16:08'),
#  ('439', '20:06'),
#  ('1665', '45:02'),
#  ('690', '07:37'),
#  ('715', '31:03'),
#  ('795', '17:17'),
#  ('1266', '73:27'),
#  ('554', '15:23'),
#  ('3020', '67:20'),
#  ('1054', '14:59')]

# %%
# url_list 用于 得到所有的 url
url
# Out:
# 'http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=742470'

# %%
no_page = int(re.findall('pages":(\d+)', str(requests.get(url).content))[0])

# %%
url_list = []
for i in range(1, no_page+1):
    url_list.append('http://space.bilibili.com/ajax/member/getSubmitVideos?page=%d&mid=742470' % i)

# %%
url_list
# Out:
# ['http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=742470',
#  'http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=742470',
#  'http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=742470',
#  'http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=742470',
#  'http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=742470',
#  'http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=742470',
#  'http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=742470',
#  'http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=742470']

# %%
# 做一个 list，里面包含诸多 dict，每一个 dict内包含所有的其他属性
videos = []
index = 0
for url in url_list:
    url_page = codecs.decode(requests.get(url).content, 'unicode_escape')
    spider1_1 = re.findall('aid":(\d+).{1,50}title":"(.{1,50})","sub.{1,50}play":(\d+),"review":(\d+),"video_review":(\d+),"favorites":(\d+)', url_page)
    spider1_2 = re.findall('comment":(\d+),"length":"([\d:]+)', url_page)    
    spider1_2_index = 0 # 为 spider_1_2做 index，每次大循环后重置
    for tuples in spider1_1:
        videos.append(dict())
        videos[index]['aid'] = tuples[0]
        videos[index]['title'] = tuples[1]
        videos[index]['play'] = tuples[2]
        videos[index]['review'] = tuples[3]
        videos[index]['video_review'] = tuples[4]
        videos[index]['favorites'] = tuples[5]
        videos[index]['comment'] = spider1_2[spider1_2_index][0] 
        videos[index]['length'] = spider1_2[spider1_2_index][1]
        index += 1
        spider1_2_index += 1
videos
# Out:
# [{'aid': '9137695',
#   'comment': '881',
#   'favorites': '239',
#   'length': '64:48',
#   'play': '23795',
#   'review': '243',
#   'title': '冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）',
#   'video_review': '881'},
#  {'aid': '9122374',
#   'comment': '512',
#   'favorites': '117',
#   'length': '92:58',
#   'play': '14183',
#   'review': '122',
#   'title': '冰冷解说：“荒竹反击流”协同斗技首秀',
#   'video_review': '512'},
#  {'aid': '9109711',
#   'comment': '822',
#   'favorites': '986',
#   'length': '07:21',
#   'play': '96186',
#   'review': '743',
#   'title': '【阴阳师】针女荒VS石踞\\/年兽+万年竹全传记！',
#   'video_review': '822'},
#  {'aid': '9071355',
#   'comment': '3027',
#   'favorites': '482',
#   'length': '41:55',
#   'play': '56359',
#   'review': '846',
#   'title': '【体验服快报】第005期：荒\\/万年竹\\/新版荒川\\/樱花妖等',
#   'video_review': '3027'},
#  {'aid': '9047855',
#   'comment': '605',
#   'favorites': '144',
#   'length': '70:00',
#   'play': '22233',
#   'review': '149',
#   'title': '冰冷解说：妇女节特辑！全女式神斗技实况（孟婆、烟烟罗等）',
#   'video_review': '605'},
#  {'aid': '9014983',
#   'comment': '915',
#   'favorites': '426',
#   'length': '109:19',
#   'play': '27805',
#   'review': '308',
#   'title': '冰冷解说：阴阳师视频攻略031 椒图反击流之酒吞队',
#   'video_review': '915'},
#  {'aid': '8941842',
#   'comment': '1042',
#   'favorites': '451',
#   'length': '60:26',
#   'play': '51955',
#   'review': '271',
#   'title': '冰冷解说：阴阳师黑科技005 万箭穿心流',
#   'video_review': '1042'},
#  {'aid': '8850760',
#   'comment': '1167',
#   'favorites': '230',
#   'length': '71:15',
#   'play': '56293',
#   'review': '281',
#   'title': '冰冷解说：体验服六星河童斗技首秀o(∩_∩)o',
#   'video_review': '1167'},
#  {'aid': '8803411',
#   'comment': '1699',
#   'favorites': '206',
#   'length': '54:57',
#   'play': '39767',
#   'review': '336',
#   'title': '【体验服快报】第004期：河畔童谣副本通关实况',
#   'video_review': '1699'},
#  {'aid': '8778401',
#   'comment': '1649',
#   'favorites': '504',
#   'length': '89:02',
#   'play': '45891',
#   'review': '429',
#   'title': '冰冷解说：“三琴余音流”斗技实况教学',
#   'video_review': '1649'},
#  {'aid': '8749188',
#   'comment': '241',
#   'favorites': '124',
#   'length': '16:08',
#   'play': '15731',
#   'review': '250',
#   'title': '冰冷解说：阴阳师全式神介绍之孟婆',
#   'video_review': '241'},
#  {'aid': '8688869',
#   'comment': '439',
#   'favorites': '167',
#   'length': '20:06',
#   'play': '21434',
#   'review': '309',
#   'title': '冰冷解说：阴阳师全式神介绍之雨女',
#   'video_review': '439'},
#  {'aid': '8665552',
#   'comment': '1665',
#   'favorites': '258',
#   'length': '45:02',
#   'play': '51843',
#   'review': '379',
#   'title': '【体验服快报】第003期：卖御魂\\/古笼火加强\\/雨女加强\\/魅妖加强',
#   'video_review': '1665'},
#  {'aid': '8648632',
#   'comment': '690',
#   'favorites': '42',
#   'length': '07:37',
#   'play': '27163',
#   'review': '591',
#   'title': '【FGO】萌新100抽测试一下血统！',
#   'video_review': '690'},
#  {'aid': '8627224',
#   'comment': '715',
#   'favorites': '404',
#   'length': '31:03',
#   'play': '30848',
#   'review': '531',
#   'title': '冰冷解说：阴阳师全式神介绍之雪女',
#   'video_review': '715'},
#  {'aid': '8569924',
#   'comment': '795',
#   'favorites': '676',
#   'length': '17:17',
#   'play': '36180',
#   'review': '391',
#   'title': '冰冷解说：阴阳师全式神介绍之妖琴师',
#   'video_review': '795'},
#  {'aid': '8528436',
#   'comment': '1270',
#   'favorites': '291',
#   'length': '73:27',
#   'play': '52378',
#   'review': '335',
#   'title': '冰冷解说：后手肉控流大战般若速控队（六星管狐+烟烟罗）',
#   'video_review': '1270'},
#  {'aid': '8450714',
#   'comment': '554',
#   'favorites': '480',
#   'length': '15:23',
#   'play': '57122',
#   'review': '311',
#   'title': '冰冷解说：阴阳师全式神介绍之烟烟罗',
#   'video_review': '554'},
#  {'aid': '8325651',
#   'comment': '3020',
#   'favorites': '4673',
#   'length': '67:20',
#   'play': '110696',
#   'review': '1014',
#   'title': '冰冷解说：阴阳师视频攻略030 鸡肋御魂变废为宝',
#   'video_review': '3020'},
#  {'aid': '8164993',
#   'comment': '1054',
#   'favorites': '1092',
#   'length': '14:59',
#   'play': '80357',
#   'review': '443',
#   'title': '冰冷解说：阴阳师全式神介绍之黑童子',
#   'video_review': '1054'},
#  {'aid': '8148063',
#   'comment': '1117',
#   'favorites': '616',
#   'length': '22:29',
#   'play': '57164',
#   'review': '625',
#   'title': '冰冷解说：阴阳师妖刀之秘籍副本1-10层^_^',
#   'video_review': '1117'},
#  {'aid': '8127677',
#   'comment': '1279',
#   'favorites': '169',
#   'length': '31:44',
#   'play': '47825',
#   'review': '381',
#   'title': '【体验服快报】第002期：年兽副本\\/永久勾玉卡\\/新皮肤\\/经验酒壶',
#   'video_review': '1279'},
#  {'aid': '8111160',
#   'comment': '3297',
#   'favorites': '441',
#   'length': '38:44',
#   'play': '79891',
#   'review': '654',
#   'title': '【体验服快报】第001期：新版小鹿男\\/烟烟罗\\/辉夜姬\\/孟婆\\/傀儡师',
#   'video_review': '3297'},
#  {'aid': '8056933',
#   'comment': '1824',
#   'favorites': '140',
#   'length': '60:33',
#   'play': '48272',
#   'review': '233',
#   'title': '【冰冷出品】火姬流反击队斗技实况（全服20名）',
#   'video_review': '1824'},
#  {'aid': '8049943',
#   'comment': '1069',
#   'favorites': '614',
#   'length': '57:59',
#   'play': '46642',
#   'review': '408',
#   'title': '冰冷解说：阴阳师视频攻略029 椒图反击流之吸血姬队',
#   'video_review': '1069'},
#  {'aid': '8032150',
#   'comment': '437',
#   'favorites': '47',
#   'length': '65:15',
#   'play': '23452',
#   'review': '157',
#   'title': '冰冷解说：小号&quot;高端&quot;斗技实况！ （1月15日）',
#   'video_review': '437'},
#  {'aid': '7950766',
#   'comment': '787',
#   'favorites': '79',
#   'length': '69:28',
#   'play': '31485',
#   'review': '221',
#   'title': '冰冷解说：小号&quot;高端&quot;斗技实况！ （1月10日）',
#   'video_review': '787'},
#  {'aid': '7926624',
#   'comment': '1283',
#   'favorites': '157',
#   'length': '65:33',
#   'play': '48918',
#   'review': '192',
#   'title': '冰冷解说：周一斗技直冲全服前20实况（1.9中午）',
#   'video_review': '1283'},
#  {'aid': '7908881',
#   'comment': '699',
#   'favorites': '99',
#   'length': '59:59',
#   'play': '23621',
#   'review': '206',
#   'title': '冰冷解说：小号“高端”斗技实况！（1月7日）',
#   'video_review': '699'},
#  {'aid': '7902584',
#   'comment': '1124',
#   'favorites': '1009',
#   'length': '21:08',
#   'play': '74091',
#   'review': '673',
#   'title': '冰冷解说：阴阳师全式神介绍之妖刀姬',
#   'video_review': '1124'},
#  {'aid': '7870583',
#   'comment': '1800',
#   'favorites': '112',
#   'length': '103:10',
#   'play': '28288',
#   'review': '309',
#   'title': '冰冷解说：小号“高端”斗技实况！（1月5日）',
#   'video_review': '1800'},
#  {'aid': '7864306',
#   'comment': '971',
#   'favorites': '178',
#   'length': '62:17',
#   'play': '28860',
#   'review': '358',
#   'title': '冰冷解说：小号“高端”斗技实况！（1月4日）',
#   'video_review': '971'},
#  {'aid': '7863274',
#   'comment': '1087',
#   'favorites': '150',
#   'length': '65:08',
#   'play': '35566',
#   'review': '170',
#   'title': '冰冷解说：1月5日中午斗技实况 古笼火初登场^_^',
#   'video_review': '1087'},
#  {'aid': '7821087',
#   'comment': '497',
#   'favorites': '151',
#   'length': '49:27',
#   'play': '24746',
#   'review': '331',
#   'title': '冰冷解说：阴阳师视频攻略028 轮入道及其相关知识详解',
#   'video_review': '497'},
#  {'aid': '7751021',
#   'comment': '1175',
#   'favorites': '1644',
#   'length': '00:00',
#   'play': '108518',
#   'review': '900',
#   'title': '冰冷解说：阴阳师全式神介绍之鬼女红叶',
#   'video_review': '1175'},
#  {'aid': '7741800',
#   'comment': '381',
#   'favorites': '149',
#   'length': '16:27',
#   'play': '32450',
#   'review': '204',
#   'title': '冰冷解说：阴阳师黑科技004 镰鼬反戈一击的妙用',
#   'video_review': '381'},
#  {'aid': '7716062',
#   'comment': '1137',
#   'favorites': '255',
#   'length': '93:39',
#   'play': '36723',
#   'review': '334',
#   'title': '冰冷解说：阴阳师视频攻略027 浅谈新御魂对后手阵容的影响',
#   'video_review': '1137'},
#  {'aid': '7665308',
#   'comment': '1224',
#   'favorites': '534',
#   'length': '69:46',
#   'play': '76481',
#   'review': '619',
#   'title': '冰冷解说：“山兔大暴走”3-10层通关录像（不是时间静止^_^）',
#   'video_review': '1224'},
#  {'aid': '7650447',
#   'comment': '1246',
#   'favorites': '1153',
#   'length': '106:29',
#   'play': '73697',
#   'review': '249',
#   'title': '冰冷解说：阴阳师视频攻略26 清白叠毒流详解',
#   'video_review': '1246'},
#  {'aid': '7621767',
#   'comment': '708',
#   'favorites': '393',
#   'length': '11:33',
#   'play': '34589',
#   'review': '379',
#   'title': '冰冷出品：功勋犬斗技立功集锦（无解说、有字幕）',
#   'video_review': '708'},
#  {'aid': '7601370',
#   'comment': '859',
#   'favorites': '1168',
#   'length': '15:55',
#   'play': '91247',
#   'review': '676',
#   'title': '冰冷解说：阴阳师全式神介绍之桃花妖',
#   'video_review': '859'},
#  {'aid': '7496891',
#   'comment': '1372',
#   'favorites': '224',
#   'length': '93:45',
#   'play': '54531',
#   'review': '235',
#   'title': '冰冷解说：直播斗技录像【2016.12.10】（P2已更新）',
#   'video_review': '1372'},
#  {'aid': '7490832',
#   'comment': '624',
#   'favorites': '814',
#   'length': '09:53',
#   'play': '61537',
#   'review': '552',
#   'title': '冰冷解说：阴阳师全式神介绍之一目连',
#   'video_review': '624'},
#  {'aid': '7450193',
#   'comment': '689',
#   'favorites': '902',
#   'length': '10:35',
#   'play': '78055',
#   'review': '534',
#   'title': '冰冷解说：阴阳师全式神介绍之青行灯',
#   'video_review': '689'},
#  {'aid': '7418500',
#   'comment': '506',
#   'favorites': '36',
#   'length': '63:22',
#   'play': '21789',
#   'review': '123',
#   'title': '冰冷解说：直播斗技录像【2016.12.4】',
#   'video_review': '506'},
#  {'aid': '7409707',
#   'comment': '357',
#   'favorites': '38',
#   'length': '60:02',
#   'play': '15992',
#   'review': '119',
#   'title': '冰冷解说：直播斗技录像【2016.12.2】',
#   'video_review': '357'},
#  {'aid': '7404143',
#   'comment': '1299',
#   'favorites': '1072',
#   'length': '10:36',
#   'play': '97147',
#   'review': '605',
#   'title': '冰冷解说：阴阳师全式神介绍之吸血姬（更新了P2）',
#   'video_review': '1299'},
#  {'aid': '7373147',
#   'comment': '1482',
#   'favorites': '83',
#   'length': '185:57',
#   'play': '30529',
#   'review': '108',
#   'title': '12.3-4日协同斗技椒图队上分实录（已更新周日登顶录像）',
#   'video_review': '1482'},
#  {'aid': '7372029',
#   'comment': '227',
#   'favorites': '28',
#   'length': '61:27',
#   'play': '11126',
#   'review': '55',
#   'title': '冰冷解说：直播斗技录像【2016.12.1】',
#   'video_review': '227'},
#  {'aid': '7363491',
#   'comment': '253',
#   'favorites': '28',
#   'length': '67:12',
#   'play': '10621',
#   'review': '164',
#   'title': '冰冷解说：直播斗技录像【2016.11.30】',
#   'video_review': '253'},
#  {'aid': '7347545',
#   'comment': '423',
#   'favorites': '336',
#   'length': '05:13',
#   'play': '62663',
#   'review': '324',
#   'title': '冰冷解说：无火阵容初步尝试小视频~',
#   'video_review': '423'},
#  {'aid': '7340475',
#   'comment': '937',
#   'favorites': '300',
#   'length': '80:12',
#   'play': '32490',
#   'review': '275',
#   'title': '冰冷解说：阴阳师视频攻略25 控制御魂及式神详解',
#   'video_review': '937'},
#  {'aid': '7320580',
#   'comment': '281',
#   'favorites': '99',
#   'length': '63:16',
#   'play': '25097',
#   'review': '133',
#   'title': '冰冷解说：2016.11.29直播斗技录像（三味琴+魍魉狗+骰子姬）',
#   'video_review': '281'},
#  {'aid': '7239529',
#   'comment': '1437',
#   'favorites': '367',
#   'length': '118:49',
#   'play': '67620',
#   'review': '335',
#   'title': '冰冷解说：阴阳师视频攻略之跳跳家族（妹妹+大团圆已更新~）',
#   'video_review': '1437'},
#  {'aid': '7218452',
#   'comment': '509',
#   'favorites': '56',
#   'length': '324:12',
#   'play': '27611',
#   'review': '108',
#   'title': '冰冷解说：每日斗技录像【2016.11.21~2016.11.27】',
#   'video_review': '509'},
#  {'aid': '7170159',
#   'comment': '701',
#   'favorites': '473',
#   'length': '53:20',
#   'play': '52009',
#   'review': '372',
#   'title': '冰冷解说：阴阳师视频攻略24 般若御魂及阵容详解',
#   'video_review': '701'},
#  {'aid': '7129551',
#   'comment': '1946',
#   'favorites': '487',
#   'length': '94:21',
#   'play': '60715',
#   'review': '438',
#   'title': '冰冷解说：阴阳师双11资料片游戏走向详解（附清姬玩法）',
#   'video_review': '1946'},
#  {'aid': '7117211',
#   'comment': '1298',
#   'favorites': '311',
#   'length': '66:14',
#   'play': '64372',
#   'review': '266',
#   'title': '冰冷解说：骰子鬼吸血姬+地藏一目连斗技实况',
#   'video_review': '1298'},
#  {'aid': '7113607',
#   'comment': '177',
#   'favorites': '41',
#   'length': '246:08',
#   'play': '13932',
#   'review': '161',
#   'title': '冰冷解说：阴阳师每周直播录像【2016.11.14~2016.11.20】',
#   'video_review': '177'},
#  {'aid': '7091183',
#   'comment': '1152',
#   'favorites': '538',
#   'length': '41:09',
#   'play': '67006',
#   'review': '437',
#   'title': '冰冷解说：阴阳师视频攻略22 狗鸟佛后期转型攻略',
#   'video_review': '1152'},
#  {'aid': '7075484',
#   'comment': '491',
#   'favorites': '136',
#   'length': '19:18',
#   'play': '34401',
#   'review': '273',
#   'title': '冰冷解说：阴阳师黑科技003 克制雨女的最佳方法',
#   'video_review': '491'},
#  {'aid': '7047532',
#   'comment': '1207',
#   'favorites': '670',
#   'length': '72:50',
#   'play': '89906',
#   'review': '430',
#   'title': '冰冷解说：6星吸血姬实测及御魂搭配（新版）',
#   'video_review': '1207'},
#  {'aid': '7035242',
#   'comment': '151',
#   'favorites': '36',
#   'length': '973:20',
#   'play': '15182',
#   'review': '113',
#   'title': '冰冷解说：阴阳师每周直播录像【2016.11.07~2016.11.13】',
#   'video_review': '151'},
#  {'aid': '7017441',
#   'comment': '885',
#   'favorites': '406',
#   'length': '69:36',
#   'play': '50148',
#   'review': '320',
#   'title': '冰冷解说：阴阳师视频攻略20 控制型式神排名',
#   'video_review': '885'},
#  {'aid': '7001764',
#   'comment': '286',
#   'favorites': '391',
#   'length': '01:07',
#   'play': '49624',
#   'review': '298',
#   'title': '海房主版《一人我饮酒醉》',
#   'video_review': '286'},
#  {'aid': '6984210',
#   'comment': '1241',
#   'favorites': '286',
#   'length': '130:32',
#   'play': '40419',
#   'review': '356',
#   'title': '冰冷解说：阴阳师视频攻略19 死缠烂打型阵容详解',
#   'video_review': '1241'},
#  {'aid': '6939057',
#   'comment': '401',
#   'favorites': '165',
#   'length': '13:43',
#   'play': '41625',
#   'review': '231',
#   'title': '番外：吸血姬单刷御魂8\\/觉醒10\\/困难18',
#   'video_review': '401'},
#  {'aid': '6935317',
#   'comment': '176',
#   'favorites': '55',
#   'length': '1639:05',
#   'play': '15833',
#   'review': '98',
#   'title': '冰冷解说：阴阳师每周直播录像【2016.10.31~2016.11.06】',
#   'video_review': '176'},
#  {'aid': '6926098',
#   'comment': '1020',
#   'favorites': '590',
#   'length': '67:30',
#   'play': '52397',
#   'review': '358',
#   'title': ' 冰冷解说：阴阳师黑科技002 丑时之女用法教学',
#   'video_review': '1020'},
#  {'aid': '6900045',
#   'comment': '1039',
#   'favorites': '762',
#   'length': '65:12',
#   'play': '70995',
#   'review': '450',
#   'title': '冰冷解说：阴阳师黑科技01 “一拳超人”阵容详解',
#   'video_review': '1039'},
#  {'aid': '6853925',
#   'comment': '2351',
#   'favorites': '879',
#   'length': '84:18',
#   'play': '86118',
#   'review': '689',
#   'title': '冰冷解说：阴阳师视频攻略18 治疗型式神排名',
#   'video_review': '2351'},
#  {'aid': '6817077',
#   'comment': '825',
#   'favorites': '507',
#   'length': '1271:03',
#   'play': '42904',
#   'review': '241',
#   'title': '冰冷解说：阴阳师每周直播录像【2016.10.24~2016.10.30】',
#   'video_review': '825'},
#  {'aid': '6802218',
#   'comment': '342',
#   'favorites': '204',
#   'length': '28:47',
#   'play': '23075',
#   'review': '241',
#   'title': '冰冷解说：阴阳师视频攻略17 傀儡师速控队搭配教学',
#   'video_review': '342'},
#  {'aid': '6790139',
#   'comment': '1511',
#   'favorites': '501',
#   'length': '73:53',
#   'play': '36821',
#   'review': '289',
#   'title': '冰冷解说：阴阳师视频攻略16 酒吞肉控队搭配教学',
#   'video_review': '1511'},
#  {'aid': '6760101',
#   'comment': '3936',
#   'favorites': '506',
#   'length': '29:07',
#   'play': '72295',
#   'review': '3140',
#   'title': '送给寮办的信：想留住玩家，请动动脑子好吗？',
#   'video_review': '3936'},
#  {'aid': '6737176',
#   'comment': '3854',
#   'favorites': '4537',
#   'length': '97:42',
#   'play': '196410',
#   'review': '967',
#   'title': '冰冷解说：阴阳师视频攻略15 群体输出式神排名',
#   'video_review': '3854'},
#  {'aid': '6694233',
#   'comment': '917',
#   'favorites': '481',
#   'length': '48:56',
#   'play': '34414',
#   'review': '219',
#   'title': '冰冷解说：阴阳师视频攻略14 鬼使黑阵容搭配教学',
#   'video_review': '917'},
#  {'aid': '6674411',
#   'comment': '429',
#   'favorites': '347',
#   'length': '78:00',
#   'play': '24716',
#   'review': '178',
#   'title': '冰冷解说：阴阳师视频攻略13 速攻流斗技阵容教学',
#   'video_review': '429'},
#  {'aid': '6653814',
#   'comment': '344',
#   'favorites': '376',
#   'length': '73:00',
#   'play': '25727',
#   'review': '151',
#   'title': '冰冷解说：阴阳师视频攻略12 输出御魂进阶教学',
#   'video_review': '344'},
#  {'aid': '6629824',
#   'comment': '5106',
#   'favorites': '7403',
#   'length': '94:00',
#   'play': '269854',
#   'review': '1220',
#   'title': '冰冷解说：阴阳师视频攻略11 单体输出式神排名',
#   'video_review': '5106'},
#  {'aid': '6605703',
#   'comment': '475',
#   'favorites': '322',
#   'length': '25:39',
#   'play': '61837',
#   'review': '116',
#   'title': '冰冷解说：阴阳师视频攻略10 速刷六星御魂教学',
#   'video_review': '475'},
#  {'aid': '6588995',
#   'comment': '1604',
#   'favorites': '514',
#   'length': '54:33',
#   'play': '60559',
#   'review': '155',
#   'title': '冰冷解说：阴阳师视频攻略09 被遗忘的N级神卡！',
#   'video_review': '1604'},
#  {'aid': '6548746',
#   'comment': '634',
#   'favorites': '438',
#   'length': '43:36',
#   'play': '44317',
#   'review': '106',
#   'title': '冰冷解说：阴阳师视频攻略08 妖刀姬的18连斩！',
#   'video_review': '634'},
#  {'aid': '6519050',
#   'comment': '622',
#   'favorites': '359',
#   'length': '62:00',
#   'play': '28885',
#   'review': '111',
#   'title': '冰冷解说：阴阳师视频攻略07 茨木童子阵容教学',
#   'video_review': '622'},
#  {'aid': '6500523',
#   'comment': '1406',
#   'favorites': '127',
#   'length': '09:36',
#   'play': '30861',
#   'review': '124',
#   'title': '冰冷解说：阴阳师国庆吸欧气专用视频 13符咒出SSR！',
#   'video_review': '1406'},
#  {'aid': '6477782',
#   'comment': '883',
#   'favorites': '368',
#   'length': '94:00',
#   'play': '32175',
#   'review': '192',
#   'title': '冰冷解说：阴阳师视频攻略06 青行灯的正确用法',
#   'video_review': '883'},
#  {'aid': '6467744',
#   'comment': '926',
#   'favorites': '393',
#   'length': '70:00',
#   'play': '33498',
#   'review': '104',
#   'title': '冰冷解说：阴阳师视频攻略05 白狼队玩法教学',
#   'video_review': '926'},
#  {'aid': '6445475',
#   'comment': '466',
#   'favorites': '314',
#   'length': '47:13',
#   'play': '23915',
#   'review': '98',
#   'title': '冰冷解说：阴阳师视频攻略04 御魂玩法教学',
#   'video_review': '466'},
#  {'aid': '6402911',
#   'comment': '473',
#   'favorites': '282',
#   'length': '55:12',
#   'play': '21009',
#   'review': '76',
#   'title': '冰冷解说：阴阳师视频攻略03 斗技阵容配置教学',
#   'video_review': '473'},
#  {'aid': '6397976',
#   'comment': '307',
#   'favorites': '432',
#   'length': '42:00',
#   'play': '50225',
#   'review': '69',
#   'title': '冰冷解说：阴阳师视频攻略02 挂机刷材料教学',
#   'video_review': '307'},
#  {'aid': '6392710',
#   'comment': '1357',
#   'favorites': '942',
#   'length': '57:50',
#   'play': '89770',
#   'review': '138',
#   'title': '冰冷解说：阴阳师视频攻略01 狗粮的正确使用方法',
#   'video_review': '1357'},
#  {'aid': '4175917',
#   'comment': '24',
#   'favorites': '0',
#   'length': '22:01',
#   'play': '1342',
#   'review': '31',
#   'title': '冰冷解说：每周直播精选20160323上单潘森',
#   'video_review': '24'},
#  {'aid': '1790986',
#   'comment': '100',
#   'favorites': '3',
#   'length': '40:38',
#   'play': '1687',
#   'review': '25',
#   'title': '冰冷解说：逃生（Outlast）实况视频第一期',
#   'video_review': '100'},
#  {'aid': '1786229',
#   'comment': '31',
#   'favorites': '17',
#   'length': '17:53',
#   'play': '4447',
#   'review': '20',
#   'title': '冰冷解说：双人2级杀龙 辅助布隆二合一教学',
#   'video_review': '31'},
#  {'aid': '1775969',
#   'comment': '51',
#   'favorites': '12',
#   'length': '13:51',
#   'play': '5170',
#   'review': '12',
#   'title': '冰冷解说：英雄联盟S5掘墓人2级solo小龙教学',
#   'video_review': '51'},
#  {'aid': '1759369',
#   'comment': '7',
#   'favorites': '0',
#   'length': '50:20',
#   'play': '648',
#   'review': '4',
#   'title': '冰冷解说：“不务正业”系列之轩辕剑6第001期（剧情向）',
#   'video_review': '7'},
#  {'aid': '1734864',
#   'comment': '58',
#   'favorites': '0',
#   'length': '06:00',
#   'play': '1088',
#   'review': '35',
#   'title': '冰冷解说：Zone状态下的海公公第002期',
#   'video_review': '58'},
#  {'aid': '1634208',
#   'comment': '9',
#   'favorites': '1',
#   'length': '21:16',
#   'play': '1401',
#   'review': '3',
#   'title': '冰冷解说：风暴英雄牛头酋长新手教学',
#   'video_review': '9'},
#  {'aid': '1620503',
#   'comment': '19',
#   'favorites': '2',
#   'length': '30:53',
#   'play': '2647',
#   'review': '9',
#   'title': '冰冷解说：lols4半决赛OMG vs 皇族（第1\\/5场）',
#   'video_review': '19'},
#  {'aid': '1563090',
#   'comment': '18',
#   'favorites': '2',
#   'length': '00:00',
#   'play': '3048',
#   'review': '16',
#   'title': '冰冷解说：lolS4总决赛小组赛OMG VS SSB',
#   'video_review': '18'},
#  {'aid': '1551370',
#   'comment': '31',
#   'favorites': '2',
#   'length': '34:38',
#   'play': '2826',
#   'review': '5',
#   'title': '冰冷解说：lolS4总决赛小组赛皇族 VS SK',
#   'video_review': '31'},
#  {'aid': '1503531',
#   'comment': '101',
#   'favorites': '21',
#   'length': '42:16',
#   'play': '3444',
#   'review': '25',
#   'title': '冰冷解说:lol牛头辅助新手教学 WQ二连包教包会！',
#   'video_review': '101'},
#  {'aid': '1472895',
#   'comment': '98',
#   'favorites': '15',
#   'length': '26:33',
#   'play': '2392',
#   'review': '17',
#   'title': '冰冷解说:IG可可辅助锤石OB视角教学',
#   'video_review': '98'},
#  {'aid': '1438455',
#   'comment': '74',
#   'favorites': '2',
#   'length': '06:59',
#   'play': '1793',
#   'review': '36',
#   'title': '冰冷解说：Zone状态下的海公公第001期',
#   'video_review': '74'},
#  {'aid': '1414291',
#   'comment': '436',
#   'favorites': '49',
#   'length': '75:47',
#   'play': '5350',
#   'review': '36',
#   'title': '冰冷解说：lol风暴之怒迦娜进阶教学（S4）',
#   'video_review': '436'},
#  {'aid': '1357833',
#   'comment': '369',
#   'favorites': '91',
#   'length': '91:18',
#   'play': '8280',
#   'review': '48',
#   'title': '冰冷解说：lol曙光女神蕾欧娜进阶教学(S4)',
#   'video_review': '369'},
#  {'aid': '1255158',
#   'comment': '111',
#   'favorites': '7',
#   'length': '108:55',
#   'play': '4775',
#   'review': '17',
#   'title': '冰冷解说：lol新玩法实验室第02期 狗头人辅助教学',
#   'video_review': '111'},
#  {'aid': '1212870',
#   'comment': '237',
#   'favorites': '88',
#   'length': '78:20',
#   'play': '4935',
#   'review': '19',
#   'title': '冰冷解说：饥荒新手过冬教学',
#   'video_review': '237'},
#  {'aid': '1090630',
#   'comment': '148',
#   'favorites': '14',
#   'length': '00:00',
#   'play': '3117',
#   'review': '21',
#   'title': '冰冷解说：英雄联盟S4上单狼人新手教学',
#   'video_review': '148'},
#  {'aid': '777285',
#   'comment': '82',
#   'favorites': '61',
#   'length': '20:06',
#   'play': '5745',
#   'review': '12',
#   'title': '冰冷解说：lol视频攻略合集-风女迦娜',
#   'video_review': '82'},
#  {'aid': '746456',
#   'comment': '91',
#   'favorites': '5',
#   'length': '61:56',
#   'play': '1625',
#   'review': '9',
#   'title': '冰冷解说：坚如磐石的下路坦克 宝石骑士新手教学',
#   'video_review': '91'},
#  {'aid': '641274',
#   'comment': '464',
#   'favorites': '19',
#   'length': '32:43',
#   'play': '6927',
#   'review': '17',
#   'title': '冰冷解说：法穿鞋加三多兰！lol上单AP狼人强势回归',
#   'video_review': '464'},
#  {'aid': '519519',
#   'comment': '29',
#   'favorites': '4',
#   'length': '32:46',
#   'play': '2043',
#   'review': '1',
#   'title': '冰冷解说：lol春季赛皇族VSOMG Rui风女第一视角',
#   'video_review': '29'},
#  {'aid': '519516',
#   'comment': '104',
#   'favorites': '2',
#   'length': '47:56',
#   'play': '1724',
#   'review': '1',
#   'title': '冰冷解说：英雄联盟S3宝石骑士上单初体验',
#   'video_review': '104'},
#  {'aid': '493811',
#   'comment': '142',
#   'favorites': '13',
#   'length': '71:24',
#   'play': '4679',
#   'review': '2',
#   'title': '冰冷解说：LOL英雄联盟S3惩戒之箭韦鲁斯新手教学',
#   'video_review': '142'},
#  {'aid': '479871',
#   'comment': '65',
#   'favorites': '1',
#   'length': '39:53',
#   'play': '910',
#   'review': '1',
#   'title': '【冰冷解说】扮猪吃老虎系列之野猪妹也有春天！',
#   'video_review': '65'},
#  {'aid': '479868',
#   'comment': '287',
#   'favorites': '3',
#   'length': '33:15',
#   'play': '8102',
#   'review': '0',
#   'title': '【冰冷解说】英雄联盟S3男枪第一视角 抱了个辅助大腿！',
#   'video_review': '287'},
#  {'aid': '479867',
#   'comment': '156',
#   'favorites': '3',
#   'length': '36:42',
#   'play': '3766',
#   'review': '1',
#   'title': '【冰冷解说】英雄联盟S3玛尔扎哈中单第一视角',
#   'video_review': '156'},
#  {'aid': '479865',
#   'comment': '27',
#   'favorites': '0',
#   'length': '20:01',
#   'play': '1031',
#   'review': '2',
#   'title': '【冰冷解说】提前体验世界末日！生化战场人类大战变异者',
#   'video_review': '27'},
#  {'aid': '479862',
#   'comment': '91',
#   'favorites': '32',
#   'length': '58:40',
#   'play': '4327',
#   'review': '2',
#   'title': '【冰冷解说】LOL英雄联盟曙光女神-蕾欧娜辅助玩法教学',
#   'video_review': '91'},
#  {'aid': '479860',
#   'comment': '15',
#   'favorites': '0',
#   'length': '01:35',
#   'play': '2844',
#   'review': '7',
#   'title': '英雄联盟彩蛋系列：沃利贝尔与基兰的宿怨',
#   'video_review': '15'},
#  {'aid': '479859',
#   'comment': '23',
#   'favorites': '6',
#   'length': '04:56',
#   'play': '1631',
#   'review': '0',
#   'title': '【lol技能宝典】法外狂徒E技能穿墙位置大全',
#   'video_review': '23'},
#  {'aid': '479856',
#   'comment': '191',
#   'favorites': '18',
#   'length': '84:31',
#   'play': '17653',
#   'review': '2',
#   'title': '【冰冷解说】LOL英雄联盟未来守护者-杰斯 上单中单2合1教学',
#   'video_review': '191'},
#  {'aid': '479854',
#   'comment': '25',
#   'favorites': '4',
#   'length': '38:43',
#   'play': '2117',
#   'review': '1',
#   'title': '【冰冷解说】LOL英雄联盟熔岩巨兽-墨菲特上单玩法新手教学',
#   'video_review': '25'},
#  {'aid': '479852',
#   'comment': '6',
#   'favorites': '0',
#   'length': '10:07',
#   'play': '810',
#   'review': '1',
#   'title': '【冰冷解说】暗黑破坏神3 单刷地狱难度库勒教学',
#   'video_review': '6'},
#  {'aid': '479850',
#   'comment': '14',
#   'favorites': '1',
#   'length': '39:59',
#   'play': '1120',
#   'review': '0',
#   'title': '【冰冷解说】LOL新玩法实验室第一期：宝石骑士上单教学',
#   'video_review': '14'},
#  {'aid': '479848',
#   'comment': '40',
#   'favorites': '6',
#   'length': '76:18',
#   'play': '7443',
#   'review': '1',
#   'title': '【冰冷解说】英雄联盟掘墓者-约里克上单新手教学（S2）',
#   'video_review': '40'},
#  {'aid': '479846',
#   'comment': '67',
#   'favorites': '22',
#   'length': '57:39',
#   'play': '5449',
#   'review': '1',
#   'title': '【冰冷解说】LOL无双剑姬-菲奥娜新手教学（上单+打野）',
#   'video_review': '67'},
#  {'aid': '479845',
#   'comment': '10',
#   'favorites': '2',
#   'length': '44:04',
#   'play': '1581',
#   'review': '0',
#   'title': '【冰冷解说】LOL深海泰坦-诺提勒斯新手教学（打野）',
#   'video_review': '10'},
#  {'aid': '479843',
#   'comment': '100',
#   'favorites': '16',
#   'length': '31:12',
#   'play': '11900',
#   'review': '1',
#   'title': '【冰冷解说】LOL英雄联盟 吸血鬼中单APC打法新手教学（S2）',
#   'video_review': '100'},
#  {'aid': '479841',
#   'comment': '1251',
#   'favorites': '234',
#   'length': '57:54',
#   'play': '34847',
#   'review': '16',
#   'title': '【冰冷解说】LOL英雄联盟寒冰射手-艾希 新手教学（S2）',
#   'video_review': '1251'},
#  {'aid': '479839',
#   'comment': '37',
#   'favorites': '2',
#   'length': '63:31',
#   'play': '3284',
#   'review': '0',
#   'title': '【冰冷解说】LOL放逐之刃-锐雯打野上单二合一教学',
#   'video_review': '37'},
#  {'aid': '479838',
#   'comment': '46',
#   'favorites': '2',
#   'length': '36:13',
#   'play': '5023',
#   'review': '0',
#   'title': '【冰冷解说】LOL诅咒巨魔-特朗德尔第一视角打野教学（S2）',
#   'video_review': '46'},
#  {'aid': '479833',
#   'comment': '3',
#   'favorites': '0',
#   'length': '23:03',
#   'play': '363',
#   'review': '0',
#   'title': '【冰冷解说】2012年元旦 五解说开黑娱乐局',
#   'video_review': '3'},
#  {'aid': '479830',
#   'comment': '10',
#   'favorites': '2',
#   'length': '31:10',
#   'play': '1952',
#   'review': '0',
#   'title': '【冰冷解说】LOL战争之王潘森第一视角教学视频',
#   'video_review': '10'},
#  {'aid': '479827',
#   'comment': '37',
#   'favorites': '0',
#   'length': '35:59',
#   'play': '2393',
#   'review': '1',
#   'title': '【冰冷解说】LOL狗头人第一视角 五坦克阵容娱乐局',
#   'video_review': '37'},
#  {'aid': '479826',
#   'comment': '20',
#   'favorites': '0',
#   'length': '25:43',
#   'play': '1711',
#   'review': '4',
#   'title': '【冰冷解说】英雄联盟第一视角 荒漠屠夫-雷克顿上单教学',
#   'video_review': '20'},
#  {'aid': '479824',
#   'comment': '39',
#   'favorites': '6',
#   'length': '36:21',
#   'play': '2152',
#   'review': '0',
#   'title': '【冰冷解说】英雄联盟第一视角 大发明家-黑默丁格中单玩法教学',
#   'video_review': '39'},
#  {'aid': '479822',
#   'comment': '15',
#   'favorites': '3',
#   'length': '38:11',
#   'play': '2200',
#   'review': '1',
#   'title': '【冰冷解说】英雄联盟第一视角 狂战士-奥拉夫上单打法教学',
#   'video_review': '15'},
#  {'aid': '479821',
#   'comment': '11',
#   'favorites': '3',
#   'length': '52:06',
#   'play': '1872',
#   'review': '0',
#   'title': '【冰冷解说】英雄联盟第一视角 天启者卡尔玛AP玩法教学',
#   'video_review': '11'},
#  {'aid': '479819',
#   'comment': '12',
#   'favorites': '2',
#   'length': '33:43',
#   'play': '913',
#   'review': '2',
#   'title': '【冰冷解说】英雄联盟第一视角 扭曲树精-茂凯打野玩法教学',
#   'video_review': '12'},
#  {'aid': '479817',
#   'comment': '3',
#   'favorites': '0',
#   'length': '30:44',
#   'play': '373',
#   'review': '1',
#   'title': '【冰冷解说】LOL媒体邀请赛冠军争夺战 游久网 VS 多玩',
#   'video_review': '3'},
#  {'aid': '479812',
#   'comment': '4',
#   'favorites': '0',
#   'length': '35:42',
#   'play': '908',
#   'review': '2',
#   'title': '【冰冷解说】英雄联盟第一视角 水晶先锋-斯卡纳打野玩法教学',
#   'video_review': '4'},
#  {'aid': '479809',
#   'comment': '28',
#   'favorites': '10',
#   'length': '23:31',
#   'play': '3946',
#   'review': '3',
#   'title': '【冰冷解说】英雄联盟第一视角 流浪法师-瑞兹教学视频',
#   'video_review': '28'},
#  {'aid': '479806',
#   'comment': '28',
#   'favorites': '4',
#   'length': '33:53',
#   'play': '2171',
#   'review': '3',
#   'title': '【冰冷解说】英雄联盟第一视角 狂暴之心-凯南AP流打法教学',
#   'video_review': '28'},
#  {'aid': '479797',
#   'comment': '4',
#   'favorites': '5',
#   'length': '50:41',
#   'play': '2040',
#   'review': '24',
#   'title': '【冰冷解说】英雄联盟第一视角 沙漠死神-内瑟斯打法教学',
#   'video_review': '4'}]

# %%
# 长度正确
len(videos)
# Out:
# 146

# %%
# 清理 title里的'\\'
for i in videos:
    i['title'] = i['title'].replace('\\/','/')

# %%
# spider1成功
videos
# Out:
# [{'aid': '9137695',
#   'comment': '881',
#   'favorites': '239',
#   'length': '64:48',
#   'play': '23795',
#   'review': '243',
#   'title': '冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）',
#   'video_review': '881'},
#  {'aid': '9122374',
#   'comment': '512',
#   'favorites': '117',
#   'length': '92:58',
#   'play': '14183',
#   'review': '122',
#   'title': '冰冷解说：“荒竹反击流”协同斗技首秀',
#   'video_review': '512'},
#  {'aid': '9109711',
#   'comment': '822',
#   'favorites': '986',
#   'length': '07:21',
#   'play': '96186',
#   'review': '743',
#   'title': '【阴阳师】针女荒VS石踞/年兽+万年竹全传记！',
#   'video_review': '822'},
#  {'aid': '9071355',
#   'comment': '3027',
#   'favorites': '482',
#   'length': '41:55',
#   'play': '56359',
#   'review': '846',
#   'title': '【体验服快报】第005期：荒/万年竹/新版荒川/樱花妖等',
#   'video_review': '3027'},
#  {'aid': '9047855',
#   'comment': '605',
#   'favorites': '144',
#   'length': '70:00',
#   'play': '22233',
#   'review': '149',
#   'title': '冰冷解说：妇女节特辑！全女式神斗技实况（孟婆、烟烟罗等）',
#   'video_review': '605'},
#  {'aid': '9014983',
#   'comment': '915',
#   'favorites': '426',
#   'length': '109:19',
#   'play': '27805',
#   'review': '308',
#   'title': '冰冷解说：阴阳师视频攻略031 椒图反击流之酒吞队',
#   'video_review': '915'},
#  {'aid': '8941842',
#   'comment': '1042',
#   'favorites': '451',
#   'length': '60:26',
#   'play': '51955',
#   'review': '271',
#   'title': '冰冷解说：阴阳师黑科技005 万箭穿心流',
#   'video_review': '1042'},
#  {'aid': '8850760',
#   'comment': '1167',
#   'favorites': '230',
#   'length': '71:15',
#   'play': '56293',
#   'review': '281',
#   'title': '冰冷解说：体验服六星河童斗技首秀o(∩_∩)o',
#   'video_review': '1167'},
#  {'aid': '8803411',
#   'comment': '1699',
#   'favorites': '206',
#   'length': '54:57',
#   'play': '39767',
#   'review': '336',
#   'title': '【体验服快报】第004期：河畔童谣副本通关实况',
#   'video_review': '1699'},
#  {'aid': '8778401',
#   'comment': '1649',
#   'favorites': '504',
#   'length': '89:02',
#   'play': '45891',
#   'review': '429',
#   'title': '冰冷解说：“三琴余音流”斗技实况教学',
#   'video_review': '1649'},
#  {'aid': '8749188',
#   'comment': '241',
#   'favorites': '124',
#   'length': '16:08',
#   'play': '15731',
#   'review': '250',
#   'title': '冰冷解说：阴阳师全式神介绍之孟婆',
#   'video_review': '241'},
#  {'aid': '8688869',
#   'comment': '439',
#   'favorites': '167',
#   'length': '20:06',
#   'play': '21434',
#   'review': '309',
#   'title': '冰冷解说：阴阳师全式神介绍之雨女',
#   'video_review': '439'},
#  {'aid': '8665552',
#   'comment': '1665',
#   'favorites': '258',
#   'length': '45:02',
#   'play': '51843',
#   'review': '379',
#   'title': '【体验服快报】第003期：卖御魂/古笼火加强/雨女加强/魅妖加强',
#   'video_review': '1665'},
#  {'aid': '8648632',
#   'comment': '690',
#   'favorites': '42',
#   'length': '07:37',
#   'play': '27163',
#   'review': '591',
#   'title': '【FGO】萌新100抽测试一下血统！',
#   'video_review': '690'},
#  {'aid': '8627224',
#   'comment': '715',
#   'favorites': '404',
#   'length': '31:03',
#   'play': '30848',
#   'review': '531',
#   'title': '冰冷解说：阴阳师全式神介绍之雪女',
#   'video_review': '715'},
#  {'aid': '8569924',
#   'comment': '795',
#   'favorites': '676',
#   'length': '17:17',
#   'play': '36180',
#   'review': '391',
#   'title': '冰冷解说：阴阳师全式神介绍之妖琴师',
#   'video_review': '795'},
#  {'aid': '8528436',
#   'comment': '1270',
#   'favorites': '291',
#   'length': '73:27',
#   'play': '52378',
#   'review': '335',
#   'title': '冰冷解说：后手肉控流大战般若速控队（六星管狐+烟烟罗）',
#   'video_review': '1270'},
#  {'aid': '8450714',
#   'comment': '554',
#   'favorites': '480',
#   'length': '15:23',
#   'play': '57122',
#   'review': '311',
#   'title': '冰冷解说：阴阳师全式神介绍之烟烟罗',
#   'video_review': '554'},
#  {'aid': '8325651',
#   'comment': '3020',
#   'favorites': '4673',
#   'length': '67:20',
#   'play': '110696',
#   'review': '1014',
#   'title': '冰冷解说：阴阳师视频攻略030 鸡肋御魂变废为宝',
#   'video_review': '3020'},
#  {'aid': '8164993',
#   'comment': '1054',
#   'favorites': '1092',
#   'length': '14:59',
#   'play': '80357',
#   'review': '443',
#   'title': '冰冷解说：阴阳师全式神介绍之黑童子',
#   'video_review': '1054'},
#  {'aid': '8148063',
#   'comment': '1117',
#   'favorites': '616',
#   'length': '22:29',
#   'play': '57164',
#   'review': '625',
#   'title': '冰冷解说：阴阳师妖刀之秘籍副本1-10层^_^',
#   'video_review': '1117'},
#  {'aid': '8127677',
#   'comment': '1279',
#   'favorites': '169',
#   'length': '31:44',
#   'play': '47825',
#   'review': '381',
#   'title': '【体验服快报】第002期：年兽副本/永久勾玉卡/新皮肤/经验酒壶',
#   'video_review': '1279'},
#  {'aid': '8111160',
#   'comment': '3297',
#   'favorites': '441',
#   'length': '38:44',
#   'play': '79891',
#   'review': '654',
#   'title': '【体验服快报】第001期：新版小鹿男/烟烟罗/辉夜姬/孟婆/傀儡师',
#   'video_review': '3297'},
#  {'aid': '8056933',
#   'comment': '1824',
#   'favorites': '140',
#   'length': '60:33',
#   'play': '48272',
#   'review': '233',
#   'title': '【冰冷出品】火姬流反击队斗技实况（全服20名）',
#   'video_review': '1824'},
#  {'aid': '8049943',
#   'comment': '1069',
#   'favorites': '614',
#   'length': '57:59',
#   'play': '46642',
#   'review': '408',
#   'title': '冰冷解说：阴阳师视频攻略029 椒图反击流之吸血姬队',
#   'video_review': '1069'},
#  {'aid': '8032150',
#   'comment': '437',
#   'favorites': '47',
#   'length': '65:15',
#   'play': '23452',
#   'review': '157',
#   'title': '冰冷解说：小号&quot;高端&quot;斗技实况！ （1月15日）',
#   'video_review': '437'},
#  {'aid': '7950766',
#   'comment': '787',
#   'favorites': '79',
#   'length': '69:28',
#   'play': '31485',
#   'review': '221',
#   'title': '冰冷解说：小号&quot;高端&quot;斗技实况！ （1月10日）',
#   'video_review': '787'},
#  {'aid': '7926624',
#   'comment': '1283',
#   'favorites': '157',
#   'length': '65:33',
#   'play': '48918',
#   'review': '192',
#   'title': '冰冷解说：周一斗技直冲全服前20实况（1.9中午）',
#   'video_review': '1283'},
#  {'aid': '7908881',
#   'comment': '699',
#   'favorites': '99',
#   'length': '59:59',
#   'play': '23621',
#   'review': '206',
#   'title': '冰冷解说：小号“高端”斗技实况！（1月7日）',
#   'video_review': '699'},
#  {'aid': '7902584',
#   'comment': '1124',
#   'favorites': '1009',
#   'length': '21:08',
#   'play': '74091',
#   'review': '673',
#   'title': '冰冷解说：阴阳师全式神介绍之妖刀姬',
#   'video_review': '1124'},
#  {'aid': '7870583',
#   'comment': '1800',
#   'favorites': '112',
#   'length': '103:10',
#   'play': '28288',
#   'review': '309',
#   'title': '冰冷解说：小号“高端”斗技实况！（1月5日）',
#   'video_review': '1800'},
#  {'aid': '7864306',
#   'comment': '971',
#   'favorites': '178',
#   'length': '62:17',
#   'play': '28860',
#   'review': '358',
#   'title': '冰冷解说：小号“高端”斗技实况！（1月4日）',
#   'video_review': '971'},
#  {'aid': '7863274',
#   'comment': '1087',
#   'favorites': '150',
#   'length': '65:08',
#   'play': '35566',
#   'review': '170',
#   'title': '冰冷解说：1月5日中午斗技实况 古笼火初登场^_^',
#   'video_review': '1087'},
#  {'aid': '7821087',
#   'comment': '497',
#   'favorites': '151',
#   'length': '49:27',
#   'play': '24746',
#   'review': '331',
#   'title': '冰冷解说：阴阳师视频攻略028 轮入道及其相关知识详解',
#   'video_review': '497'},
#  {'aid': '7751021',
#   'comment': '1175',
#   'favorites': '1644',
#   'length': '00:00',
#   'play': '108518',
#   'review': '900',
#   'title': '冰冷解说：阴阳师全式神介绍之鬼女红叶',
#   'video_review': '1175'},
#  {'aid': '7741800',
#   'comment': '381',
#   'favorites': '149',
#   'length': '16:27',
#   'play': '32450',
#   'review': '204',
#   'title': '冰冷解说：阴阳师黑科技004 镰鼬反戈一击的妙用',
#   'video_review': '381'},
#  {'aid': '7716062',
#   'comment': '1137',
#   'favorites': '255',
#   'length': '93:39',
#   'play': '36723',
#   'review': '334',
#   'title': '冰冷解说：阴阳师视频攻略027 浅谈新御魂对后手阵容的影响',
#   'video_review': '1137'},
#  {'aid': '7665308',
#   'comment': '1224',
#   'favorites': '534',
#   'length': '69:46',
#   'play': '76481',
#   'review': '619',
#   'title': '冰冷解说：“山兔大暴走”3-10层通关录像（不是时间静止^_^）',
#   'video_review': '1224'},
#  {'aid': '7650447',
#   'comment': '1246',
#   'favorites': '1153',
#   'length': '106:29',
#   'play': '73697',
#   'review': '249',
#   'title': '冰冷解说：阴阳师视频攻略26 清白叠毒流详解',
#   'video_review': '1246'},
#  {'aid': '7621767',
#   'comment': '708',
#   'favorites': '393',
#   'length': '11:33',
#   'play': '34589',
#   'review': '379',
#   'title': '冰冷出品：功勋犬斗技立功集锦（无解说、有字幕）',
#   'video_review': '708'},
#  {'aid': '7601370',
#   'comment': '859',
#   'favorites': '1168',
#   'length': '15:55',
#   'play': '91247',
#   'review': '676',
#   'title': '冰冷解说：阴阳师全式神介绍之桃花妖',
#   'video_review': '859'},
#  {'aid': '7496891',
#   'comment': '1372',
#   'favorites': '224',
#   'length': '93:45',
#   'play': '54531',
#   'review': '235',
#   'title': '冰冷解说：直播斗技录像【2016.12.10】（P2已更新）',
#   'video_review': '1372'},
#  {'aid': '7490832',
#   'comment': '624',
#   'favorites': '814',
#   'length': '09:53',
#   'play': '61537',
#   'review': '552',
#   'title': '冰冷解说：阴阳师全式神介绍之一目连',
#   'video_review': '624'},
#  {'aid': '7450193',
#   'comment': '689',
#   'favorites': '902',
#   'length': '10:35',
#   'play': '78055',
#   'review': '534',
#   'title': '冰冷解说：阴阳师全式神介绍之青行灯',
#   'video_review': '689'},
#  {'aid': '7418500',
#   'comment': '506',
#   'favorites': '36',
#   'length': '63:22',
#   'play': '21789',
#   'review': '123',
#   'title': '冰冷解说：直播斗技录像【2016.12.4】',
#   'video_review': '506'},
#  {'aid': '7409707',
#   'comment': '357',
#   'favorites': '38',
#   'length': '60:02',
#   'play': '15992',
#   'review': '119',
#   'title': '冰冷解说：直播斗技录像【2016.12.2】',
#   'video_review': '357'},
#  {'aid': '7404143',
#   'comment': '1299',
#   'favorites': '1072',
#   'length': '10:36',
#   'play': '97147',
#   'review': '605',
#   'title': '冰冷解说：阴阳师全式神介绍之吸血姬（更新了P2）',
#   'video_review': '1299'},
#  {'aid': '7373147',
#   'comment': '1482',
#   'favorites': '83',
#   'length': '185:57',
#   'play': '30529',
#   'review': '108',
#   'title': '12.3-4日协同斗技椒图队上分实录（已更新周日登顶录像）',
#   'video_review': '1482'},
#  {'aid': '7372029',
#   'comment': '227',
#   'favorites': '28',
#   'length': '61:27',
#   'play': '11126',
#   'review': '55',
#   'title': '冰冷解说：直播斗技录像【2016.12.1】',
#   'video_review': '227'},
#  {'aid': '7363491',
#   'comment': '253',
#   'favorites': '28',
#   'length': '67:12',
#   'play': '10621',
#   'review': '164',
#   'title': '冰冷解说：直播斗技录像【2016.11.30】',
#   'video_review': '253'},
#  {'aid': '7347545',
#   'comment': '423',
#   'favorites': '336',
#   'length': '05:13',
#   'play': '62663',
#   'review': '324',
#   'title': '冰冷解说：无火阵容初步尝试小视频~',
#   'video_review': '423'},
#  {'aid': '7340475',
#   'comment': '937',
#   'favorites': '300',
#   'length': '80:12',
#   'play': '32490',
#   'review': '275',
#   'title': '冰冷解说：阴阳师视频攻略25 控制御魂及式神详解',
#   'video_review': '937'},
#  {'aid': '7320580',
#   'comment': '281',
#   'favorites': '99',
#   'length': '63:16',
#   'play': '25097',
#   'review': '133',
#   'title': '冰冷解说：2016.11.29直播斗技录像（三味琴+魍魉狗+骰子姬）',
#   'video_review': '281'},
#  {'aid': '7239529',
#   'comment': '1437',
#   'favorites': '367',
#   'length': '118:49',
#   'play': '67620',
#   'review': '335',
#   'title': '冰冷解说：阴阳师视频攻略之跳跳家族（妹妹+大团圆已更新~）',
#   'video_review': '1437'},
#  {'aid': '7218452',
#   'comment': '509',
#   'favorites': '56',
#   'length': '324:12',
#   'play': '27611',
#   'review': '108',
#   'title': '冰冷解说：每日斗技录像【2016.11.21~2016.11.27】',
#   'video_review': '509'},
#  {'aid': '7170159',
#   'comment': '701',
#   'favorites': '473',
#   'length': '53:20',
#   'play': '52009',
#   'review': '372',
#   'title': '冰冷解说：阴阳师视频攻略24 般若御魂及阵容详解',
#   'video_review': '701'},
#  {'aid': '7129551',
#   'comment': '1946',
#   'favorites': '487',
#   'length': '94:21',
#   'play': '60715',
#   'review': '438',
#   'title': '冰冷解说：阴阳师双11资料片游戏走向详解（附清姬玩法）',
#   'video_review': '1946'},
#  {'aid': '7117211',
#   'comment': '1298',
#   'favorites': '311',
#   'length': '66:14',
#   'play': '64372',
#   'review': '266',
#   'title': '冰冷解说：骰子鬼吸血姬+地藏一目连斗技实况',
#   'video_review': '1298'},
#  {'aid': '7113607',
#   'comment': '177',
#   'favorites': '41',
#   'length': '246:08',
#   'play': '13932',
#   'review': '161',
#   'title': '冰冷解说：阴阳师每周直播录像【2016.11.14~2016.11.20】',
#   'video_review': '177'},
#  {'aid': '7091183',
#   'comment': '1152',
#   'favorites': '538',
#   'length': '41:09',
#   'play': '67006',
#   'review': '437',
#   'title': '冰冷解说：阴阳师视频攻略22 狗鸟佛后期转型攻略',
#   'video_review': '1152'},
#  {'aid': '7075484',
#   'comment': '491',
#   'favorites': '136',
#   'length': '19:18',
#   'play': '34401',
#   'review': '273',
#   'title': '冰冷解说：阴阳师黑科技003 克制雨女的最佳方法',
#   'video_review': '491'},
#  {'aid': '7047532',
#   'comment': '1207',
#   'favorites': '670',
#   'length': '72:50',
#   'play': '89906',
#   'review': '430',
#   'title': '冰冷解说：6星吸血姬实测及御魂搭配（新版）',
#   'video_review': '1207'},
#  {'aid': '7035242',
#   'comment': '151',
#   'favorites': '36',
#   'length': '973:20',
#   'play': '15182',
#   'review': '113',
#   'title': '冰冷解说：阴阳师每周直播录像【2016.11.07~2016.11.13】',
#   'video_review': '151'},
#  {'aid': '7017441',
#   'comment': '885',
#   'favorites': '406',
#   'length': '69:36',
#   'play': '50148',
#   'review': '320',
#   'title': '冰冷解说：阴阳师视频攻略20 控制型式神排名',
#   'video_review': '885'},
#  {'aid': '7001764',
#   'comment': '286',
#   'favorites': '391',
#   'length': '01:07',
#   'play': '49624',
#   'review': '298',
#   'title': '海房主版《一人我饮酒醉》',
#   'video_review': '286'},
#  {'aid': '6984210',
#   'comment': '1241',
#   'favorites': '286',
#   'length': '130:32',
#   'play': '40419',
#   'review': '356',
#   'title': '冰冷解说：阴阳师视频攻略19 死缠烂打型阵容详解',
#   'video_review': '1241'},
#  {'aid': '6939057',
#   'comment': '401',
#   'favorites': '165',
#   'length': '13:43',
#   'play': '41625',
#   'review': '231',
#   'title': '番外：吸血姬单刷御魂8/觉醒10/困难18',
#   'video_review': '401'},
#  {'aid': '6935317',
#   'comment': '176',
#   'favorites': '55',
#   'length': '1639:05',
#   'play': '15833',
#   'review': '98',
#   'title': '冰冷解说：阴阳师每周直播录像【2016.10.31~2016.11.06】',
#   'video_review': '176'},
#  {'aid': '6926098',
#   'comment': '1020',
#   'favorites': '590',
#   'length': '67:30',
#   'play': '52397',
#   'review': '358',
#   'title': ' 冰冷解说：阴阳师黑科技002 丑时之女用法教学',
#   'video_review': '1020'},
#  {'aid': '6900045',
#   'comment': '1039',
#   'favorites': '762',
#   'length': '65:12',
#   'play': '70995',
#   'review': '450',
#   'title': '冰冷解说：阴阳师黑科技01 “一拳超人”阵容详解',
#   'video_review': '1039'},
#  {'aid': '6853925',
#   'comment': '2351',
#   'favorites': '879',
#   'length': '84:18',
#   'play': '86118',
#   'review': '689',
#   'title': '冰冷解说：阴阳师视频攻略18 治疗型式神排名',
#   'video_review': '2351'},
#  {'aid': '6817077',
#   'comment': '825',
#   'favorites': '507',
#   'length': '1271:03',
#   'play': '42904',
#   'review': '241',
#   'title': '冰冷解说：阴阳师每周直播录像【2016.10.24~2016.10.30】',
#   'video_review': '825'},
#  {'aid': '6802218',
#   'comment': '342',
#   'favorites': '204',
#   'length': '28:47',
#   'play': '23075',
#   'review': '241',
#   'title': '冰冷解说：阴阳师视频攻略17 傀儡师速控队搭配教学',
#   'video_review': '342'},
#  {'aid': '6790139',
#   'comment': '1511',
#   'favorites': '501',
#   'length': '73:53',
#   'play': '36821',
#   'review': '289',
#   'title': '冰冷解说：阴阳师视频攻略16 酒吞肉控队搭配教学',
#   'video_review': '1511'},
#  {'aid': '6760101',
#   'comment': '3936',
#   'favorites': '506',
#   'length': '29:07',
#   'play': '72295',
#   'review': '3140',
#   'title': '送给寮办的信：想留住玩家，请动动脑子好吗？',
#   'video_review': '3936'},
#  {'aid': '6737176',
#   'comment': '3854',
#   'favorites': '4537',
#   'length': '97:42',
#   'play': '196410',
#   'review': '967',
#   'title': '冰冷解说：阴阳师视频攻略15 群体输出式神排名',
#   'video_review': '3854'},
#  {'aid': '6694233',
#   'comment': '917',
#   'favorites': '481',
#   'length': '48:56',
#   'play': '34414',
#   'review': '219',
#   'title': '冰冷解说：阴阳师视频攻略14 鬼使黑阵容搭配教学',
#   'video_review': '917'},
#  {'aid': '6674411',
#   'comment': '429',
#   'favorites': '347',
#   'length': '78:00',
#   'play': '24716',
#   'review': '178',
#   'title': '冰冷解说：阴阳师视频攻略13 速攻流斗技阵容教学',
#   'video_review': '429'},
#  {'aid': '6653814',
#   'comment': '344',
#   'favorites': '376',
#   'length': '73:00',
#   'play': '25727',
#   'review': '151',
#   'title': '冰冷解说：阴阳师视频攻略12 输出御魂进阶教学',
#   'video_review': '344'},
#  {'aid': '6629824',
#   'comment': '5106',
#   'favorites': '7403',
#   'length': '94:00',
#   'play': '269854',
#   'review': '1220',
#   'title': '冰冷解说：阴阳师视频攻略11 单体输出式神排名',
#   'video_review': '5106'},
#  {'aid': '6605703',
#   'comment': '475',
#   'favorites': '322',
#   'length': '25:39',
#   'play': '61837',
#   'review': '116',
#   'title': '冰冷解说：阴阳师视频攻略10 速刷六星御魂教学',
#   'video_review': '475'},
#  {'aid': '6588995',
#   'comment': '1604',
#   'favorites': '514',
#   'length': '54:33',
#   'play': '60559',
#   'review': '155',
#   'title': '冰冷解说：阴阳师视频攻略09 被遗忘的N级神卡！',
#   'video_review': '1604'},
#  {'aid': '6548746',
#   'comment': '634',
#   'favorites': '438',
#   'length': '43:36',
#   'play': '44317',
#   'review': '106',
#   'title': '冰冷解说：阴阳师视频攻略08 妖刀姬的18连斩！',
#   'video_review': '634'},
#  {'aid': '6519050',
#   'comment': '622',
#   'favorites': '359',
#   'length': '62:00',
#   'play': '28885',
#   'review': '111',
#   'title': '冰冷解说：阴阳师视频攻略07 茨木童子阵容教学',
#   'video_review': '622'},
#  {'aid': '6500523',
#   'comment': '1406',
#   'favorites': '127',
#   'length': '09:36',
#   'play': '30861',
#   'review': '124',
#   'title': '冰冷解说：阴阳师国庆吸欧气专用视频 13符咒出SSR！',
#   'video_review': '1406'},
#  {'aid': '6477782',
#   'comment': '883',
#   'favorites': '368',
#   'length': '94:00',
#   'play': '32175',
#   'review': '192',
#   'title': '冰冷解说：阴阳师视频攻略06 青行灯的正确用法',
#   'video_review': '883'},
#  {'aid': '6467744',
#   'comment': '926',
#   'favorites': '393',
#   'length': '70:00',
#   'play': '33498',
#   'review': '104',
#   'title': '冰冷解说：阴阳师视频攻略05 白狼队玩法教学',
#   'video_review': '926'},
#  {'aid': '6445475',
#   'comment': '466',
#   'favorites': '314',
#   'length': '47:13',
#   'play': '23915',
#   'review': '98',
#   'title': '冰冷解说：阴阳师视频攻略04 御魂玩法教学',
#   'video_review': '466'},
#  {'aid': '6402911',
#   'comment': '473',
#   'favorites': '282',
#   'length': '55:12',
#   'play': '21009',
#   'review': '76',
#   'title': '冰冷解说：阴阳师视频攻略03 斗技阵容配置教学',
#   'video_review': '473'},
#  {'aid': '6397976',
#   'comment': '307',
#   'favorites': '432',
#   'length': '42:00',
#   'play': '50225',
#   'review': '69',
#   'title': '冰冷解说：阴阳师视频攻略02 挂机刷材料教学',
#   'video_review': '307'},
#  {'aid': '6392710',
#   'comment': '1357',
#   'favorites': '942',
#   'length': '57:50',
#   'play': '89770',
#   'review': '138',
#   'title': '冰冷解说：阴阳师视频攻略01 狗粮的正确使用方法',
#   'video_review': '1357'},
#  {'aid': '4175917',
#   'comment': '24',
#   'favorites': '0',
#   'length': '22:01',
#   'play': '1342',
#   'review': '31',
#   'title': '冰冷解说：每周直播精选20160323上单潘森',
#   'video_review': '24'},
#  {'aid': '1790986',
#   'comment': '100',
#   'favorites': '3',
#   'length': '40:38',
#   'play': '1687',
#   'review': '25',
#   'title': '冰冷解说：逃生（Outlast）实况视频第一期',
#   'video_review': '100'},
#  {'aid': '1786229',
#   'comment': '31',
#   'favorites': '17',
#   'length': '17:53',
#   'play': '4447',
#   'review': '20',
#   'title': '冰冷解说：双人2级杀龙 辅助布隆二合一教学',
#   'video_review': '31'},
#  {'aid': '1775969',
#   'comment': '51',
#   'favorites': '12',
#   'length': '13:51',
#   'play': '5170',
#   'review': '12',
#   'title': '冰冷解说：英雄联盟S5掘墓人2级solo小龙教学',
#   'video_review': '51'},
#  {'aid': '1759369',
#   'comment': '7',
#   'favorites': '0',
#   'length': '50:20',
#   'play': '648',
#   'review': '4',
#   'title': '冰冷解说：“不务正业”系列之轩辕剑6第001期（剧情向）',
#   'video_review': '7'},
#  {'aid': '1734864',
#   'comment': '58',
#   'favorites': '0',
#   'length': '06:00',
#   'play': '1088',
#   'review': '35',
#   'title': '冰冷解说：Zone状态下的海公公第002期',
#   'video_review': '58'},
#  {'aid': '1634208',
#   'comment': '9',
#   'favorites': '1',
#   'length': '21:16',
#   'play': '1401',
#   'review': '3',
#   'title': '冰冷解说：风暴英雄牛头酋长新手教学',
#   'video_review': '9'},
#  {'aid': '1620503',
#   'comment': '19',
#   'favorites': '2',
#   'length': '30:53',
#   'play': '2647',
#   'review': '9',
#   'title': '冰冷解说：lols4半决赛OMG vs 皇族（第1/5场）',
#   'video_review': '19'},
#  {'aid': '1563090',
#   'comment': '18',
#   'favorites': '2',
#   'length': '00:00',
#   'play': '3048',
#   'review': '16',
#   'title': '冰冷解说：lolS4总决赛小组赛OMG VS SSB',
#   'video_review': '18'},
#  {'aid': '1551370',
#   'comment': '31',
#   'favorites': '2',
#   'length': '34:38',
#   'play': '2826',
#   'review': '5',
#   'title': '冰冷解说：lolS4总决赛小组赛皇族 VS SK',
#   'video_review': '31'},
#  {'aid': '1503531',
#   'comment': '101',
#   'favorites': '21',
#   'length': '42:16',
#   'play': '3444',
#   'review': '25',
#   'title': '冰冷解说:lol牛头辅助新手教学 WQ二连包教包会！',
#   'video_review': '101'},
#  {'aid': '1472895',
#   'comment': '98',
#   'favorites': '15',
#   'length': '26:33',
#   'play': '2392',
#   'review': '17',
#   'title': '冰冷解说:IG可可辅助锤石OB视角教学',
#   'video_review': '98'},
#  {'aid': '1438455',
#   'comment': '74',
#   'favorites': '2',
#   'length': '06:59',
#   'play': '1793',
#   'review': '36',
#   'title': '冰冷解说：Zone状态下的海公公第001期',
#   'video_review': '74'},
#  {'aid': '1414291',
#   'comment': '436',
#   'favorites': '49',
#   'length': '75:47',
#   'play': '5350',
#   'review': '36',
#   'title': '冰冷解说：lol风暴之怒迦娜进阶教学（S4）',
#   'video_review': '436'},
#  {'aid': '1357833',
#   'comment': '369',
#   'favorites': '91',
#   'length': '91:18',
#   'play': '8280',
#   'review': '48',
#   'title': '冰冷解说：lol曙光女神蕾欧娜进阶教学(S4)',
#   'video_review': '369'},
#  {'aid': '1255158',
#   'comment': '111',
#   'favorites': '7',
#   'length': '108:55',
#   'play': '4775',
#   'review': '17',
#   'title': '冰冷解说：lol新玩法实验室第02期 狗头人辅助教学',
#   'video_review': '111'},
#  {'aid': '1212870',
#   'comment': '237',
#   'favorites': '88',
#   'length': '78:20',
#   'play': '4935',
#   'review': '19',
#   'title': '冰冷解说：饥荒新手过冬教学',
#   'video_review': '237'},
#  {'aid': '1090630',
#   'comment': '148',
#   'favorites': '14',
#   'length': '00:00',
#   'play': '3117',
#   'review': '21',
#   'title': '冰冷解说：英雄联盟S4上单狼人新手教学',
#   'video_review': '148'},
#  {'aid': '777285',
#   'comment': '82',
#   'favorites': '61',
#   'length': '20:06',
#   'play': '5745',
#   'review': '12',
#   'title': '冰冷解说：lol视频攻略合集-风女迦娜',
#   'video_review': '82'},
#  {'aid': '746456',
#   'comment': '91',
#   'favorites': '5',
#   'length': '61:56',
#   'play': '1625',
#   'review': '9',
#   'title': '冰冷解说：坚如磐石的下路坦克 宝石骑士新手教学',
#   'video_review': '91'},
#  {'aid': '641274',
#   'comment': '464',
#   'favorites': '19',
#   'length': '32:43',
#   'play': '6927',
#   'review': '17',
#   'title': '冰冷解说：法穿鞋加三多兰！lol上单AP狼人强势回归',
#   'video_review': '464'},
#  {'aid': '519519',
#   'comment': '29',
#   'favorites': '4',
#   'length': '32:46',
#   'play': '2043',
#   'review': '1',
#   'title': '冰冷解说：lol春季赛皇族VSOMG Rui风女第一视角',
#   'video_review': '29'},
#  {'aid': '519516',
#   'comment': '104',
#   'favorites': '2',
#   'length': '47:56',
#   'play': '1724',
#   'review': '1',
#   'title': '冰冷解说：英雄联盟S3宝石骑士上单初体验',
#   'video_review': '104'},
#  {'aid': '493811',
#   'comment': '142',
#   'favorites': '13',
#   'length': '71:24',
#   'play': '4679',
#   'review': '2',
#   'title': '冰冷解说：LOL英雄联盟S3惩戒之箭韦鲁斯新手教学',
#   'video_review': '142'},
#  {'aid': '479871',
#   'comment': '65',
#   'favorites': '1',
#   'length': '39:53',
#   'play': '910',
#   'review': '1',
#   'title': '【冰冷解说】扮猪吃老虎系列之野猪妹也有春天！',
#   'video_review': '65'},
#  {'aid': '479868',
#   'comment': '287',
#   'favorites': '3',
#   'length': '33:15',
#   'play': '8102',
#   'review': '0',
#   'title': '【冰冷解说】英雄联盟S3男枪第一视角 抱了个辅助大腿！',
#   'video_review': '287'},
#  {'aid': '479867',
#   'comment': '156',
#   'favorites': '3',
#   'length': '36:42',
#   'play': '3766',
#   'review': '1',
#   'title': '【冰冷解说】英雄联盟S3玛尔扎哈中单第一视角',
#   'video_review': '156'},
#  {'aid': '479865',
#   'comment': '27',
#   'favorites': '0',
#   'length': '20:01',
#   'play': '1031',
#   'review': '2',
#   'title': '【冰冷解说】提前体验世界末日！生化战场人类大战变异者',
#   'video_review': '27'},
#  {'aid': '479862',
#   'comment': '91',
#   'favorites': '32',
#   'length': '58:40',
#   'play': '4327',
#   'review': '2',
#   'title': '【冰冷解说】LOL英雄联盟曙光女神-蕾欧娜辅助玩法教学',
#   'video_review': '91'},
#  {'aid': '479860',
#   'comment': '15',
#   'favorites': '0',
#   'length': '01:35',
#   'play': '2844',
#   'review': '7',
#   'title': '英雄联盟彩蛋系列：沃利贝尔与基兰的宿怨',
#   'video_review': '15'},
#  {'aid': '479859',
#   'comment': '23',
#   'favorites': '6',
#   'length': '04:56',
#   'play': '1631',
#   'review': '0',
#   'title': '【lol技能宝典】法外狂徒E技能穿墙位置大全',
#   'video_review': '23'},
#  {'aid': '479856',
#   'comment': '191',
#   'favorites': '18',
#   'length': '84:31',
#   'play': '17653',
#   'review': '2',
#   'title': '【冰冷解说】LOL英雄联盟未来守护者-杰斯 上单中单2合1教学',
#   'video_review': '191'},
#  {'aid': '479854',
#   'comment': '25',
#   'favorites': '4',
#   'length': '38:43',
#   'play': '2117',
#   'review': '1',
#   'title': '【冰冷解说】LOL英雄联盟熔岩巨兽-墨菲特上单玩法新手教学',
#   'video_review': '25'},
#  {'aid': '479852',
#   'comment': '6',
#   'favorites': '0',
#   'length': '10:07',
#   'play': '810',
#   'review': '1',
#   'title': '【冰冷解说】暗黑破坏神3 单刷地狱难度库勒教学',
#   'video_review': '6'},
#  {'aid': '479850',
#   'comment': '14',
#   'favorites': '1',
#   'length': '39:59',
#   'play': '1120',
#   'review': '0',
#   'title': '【冰冷解说】LOL新玩法实验室第一期：宝石骑士上单教学',
#   'video_review': '14'},
#  {'aid': '479848',
#   'comment': '40',
#   'favorites': '6',
#   'length': '76:18',
#   'play': '7443',
#   'review': '1',
#   'title': '【冰冷解说】英雄联盟掘墓者-约里克上单新手教学（S2）',
#   'video_review': '40'},
#  {'aid': '479846',
#   'comment': '67',
#   'favorites': '22',
#   'length': '57:39',
#   'play': '5449',
#   'review': '1',
#   'title': '【冰冷解说】LOL无双剑姬-菲奥娜新手教学（上单+打野）',
#   'video_review': '67'},
#  {'aid': '479845',
#   'comment': '10',
#   'favorites': '2',
#   'length': '44:04',
#   'play': '1581',
#   'review': '0',
#   'title': '【冰冷解说】LOL深海泰坦-诺提勒斯新手教学（打野）',
#   'video_review': '10'},
#  {'aid': '479843',
#   'comment': '100',
#   'favorites': '16',
#   'length': '31:12',
#   'play': '11900',
#   'review': '1',
#   'title': '【冰冷解说】LOL英雄联盟 吸血鬼中单APC打法新手教学（S2）',
#   'video_review': '100'},
#  {'aid': '479841',
#   'comment': '1251',
#   'favorites': '234',
#   'length': '57:54',
#   'play': '34847',
#   'review': '16',
#   'title': '【冰冷解说】LOL英雄联盟寒冰射手-艾希 新手教学（S2）',
#   'video_review': '1251'},
#  {'aid': '479839',
#   'comment': '37',
#   'favorites': '2',
#   'length': '63:31',
#   'play': '3284',
#   'review': '0',
#   'title': '【冰冷解说】LOL放逐之刃-锐雯打野上单二合一教学',
#   'video_review': '37'},
#  {'aid': '479838',
#   'comment': '46',
#   'favorites': '2',
#   'length': '36:13',
#   'play': '5023',
#   'review': '0',
#   'title': '【冰冷解说】LOL诅咒巨魔-特朗德尔第一视角打野教学（S2）',
#   'video_review': '46'},
#  {'aid': '479833',
#   'comment': '3',
#   'favorites': '0',
#   'length': '23:03',
#   'play': '363',
#   'review': '0',
#   'title': '【冰冷解说】2012年元旦 五解说开黑娱乐局',
#   'video_review': '3'},
#  {'aid': '479830',
#   'comment': '10',
#   'favorites': '2',
#   'length': '31:10',
#   'play': '1952',
#   'review': '0',
#   'title': '【冰冷解说】LOL战争之王潘森第一视角教学视频',
#   'video_review': '10'},
#  {'aid': '479827',
#   'comment': '37',
#   'favorites': '0',
#   'length': '35:59',
#   'play': '2393',
#   'review': '1',
#   'title': '【冰冷解说】LOL狗头人第一视角 五坦克阵容娱乐局',
#   'video_review': '37'},
#  {'aid': '479826',
#   'comment': '20',
#   'favorites': '0',
#   'length': '25:43',
#   'play': '1711',
#   'review': '4',
#   'title': '【冰冷解说】英雄联盟第一视角 荒漠屠夫-雷克顿上单教学',
#   'video_review': '20'},
#  {'aid': '479824',
#   'comment': '39',
#   'favorites': '6',
#   'length': '36:21',
#   'play': '2152',
#   'review': '0',
#   'title': '【冰冷解说】英雄联盟第一视角 大发明家-黑默丁格中单玩法教学',
#   'video_review': '39'},
#  {'aid': '479822',
#   'comment': '15',
#   'favorites': '3',
#   'length': '38:11',
#   'play': '2200',
#   'review': '1',
#   'title': '【冰冷解说】英雄联盟第一视角 狂战士-奥拉夫上单打法教学',
#   'video_review': '15'},
#  {'aid': '479821',
#   'comment': '11',
#   'favorites': '3',
#   'length': '52:06',
#   'play': '1872',
#   'review': '0',
#   'title': '【冰冷解说】英雄联盟第一视角 天启者卡尔玛AP玩法教学',
#   'video_review': '11'},
#  {'aid': '479819',
#   'comment': '12',
#   'favorites': '2',
#   'length': '33:43',
#   'play': '913',
#   'review': '2',
#   'title': '【冰冷解说】英雄联盟第一视角 扭曲树精-茂凯打野玩法教学',
#   'video_review': '12'},
#  {'aid': '479817',
#   'comment': '3',
#   'favorites': '0',
#   'length': '30:44',
#   'play': '373',
#   'review': '1',
#   'title': '【冰冷解说】LOL媒体邀请赛冠军争夺战 游久网 VS 多玩',
#   'video_review': '3'},
#  {'aid': '479812',
#   'comment': '4',
#   'favorites': '0',
#   'length': '35:42',
#   'play': '908',
#   'review': '2',
#   'title': '【冰冷解说】英雄联盟第一视角 水晶先锋-斯卡纳打野玩法教学',
#   'video_review': '4'},
#  {'aid': '479809',
#   'comment': '28',
#   'favorites': '10',
#   'length': '23:31',
#   'play': '3946',
#   'review': '3',
#   'title': '【冰冷解说】英雄联盟第一视角 流浪法师-瑞兹教学视频',
#   'video_review': '28'},
#  {'aid': '479806',
#   'comment': '28',
#   'favorites': '4',
#   'length': '33:53',
#   'play': '2171',
#   'review': '3',
#   'title': '【冰冷解说】英雄联盟第一视角 狂暴之心-凯南AP流打法教学',
#   'video_review': '28'},
#  {'aid': '479797',
#   'comment': '4',
#   'favorites': '5',
#   'length': '50:41',
#   'play': '2040',
#   'review': '24',
#   'title': '【冰冷解说】英雄联盟第一视角 沙漠死神-内瑟斯打法教学',
#   'video_review': '4'}]

# %%
# 要注意 dict里所有数字都是 str
type(videos[0]['aid'])
# Out:
# str

# %% [markdown]
# ### 爬取信息二：spider2

# %%
# 提取 videos里的信息，得到 aid
# 之后进入新网站提取 coin
# 添加 coin到相应的 dict
spider2_url = 'http://api.bilibili.com/archive_stat/stat?aid='

# %%
# 查看新网站结构，以 aid=9109711 测试
print(requests.get(spider2_url + str(9109711)).content)
print(type(requests.get(spider2_url + str(9109711)).content))
# Out:
# b'{"code":0,"data":{"view":96228,"danmaku":822,"reply":744,"favorite":986,"coin":681,"share":887,"now_rank":0,"his_rank":0},"message":""}'
# <class 'bytes'>

# %%
# 得到 coin信息
print(re.findall('coin":(\d+)', str(requests.get(spider2_url + str(9109711)).content))[0])
print(type(re.findall('coin":(\d+)', str(requests.get(spider2_url + str(9109711)).content))[0]))
# Out:
# 681
# <class 'str'>

# %%
# 构建 spider2
for i in videos:
    aid = i['aid']
    url = spider2_url + aid # 因为 aid是 str，所以不需要 convert
    coin = re.findall('coin":(\d+)', str(requests.get(url).content))[0]
    i['coin'] = coin
videos[:2]
# Out:
# [{'aid': '9137695',
#   'coin': '461',
#   'comment': '881',
#   'favorites': '239',
#   'length': '64:48',
#   'play': '23795',
#   'review': '243',
#   'title': '冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）',
#   'video_review': '881'},
#  {'aid': '9122374',
#   'coin': '199',
#   'comment': '512',
#   'favorites': '117',
#   'length': '92:58',
#   'play': '14183',
#   'review': '122',
#   'title': '冰冷解说：“荒竹反击流”协同斗技首秀',
#   'video_review': '512'}]

# %%
# spider2成功
len(videos)
# Out:
# 146

# %% [markdown]
# ### 爬取信息三：spider3

# %%
# 同样要使用 aid信息
# 进入 url
# 用 BS得到日期和时间（考虑到以后可能会用到具体时间）
# 添加到 videos
spider3_url = 'http://www.bilibili.com/video/av'

# %%
# 以 aid=9109711 测试
test_time = BS(requests.get(spider3_url + str(9109711)).content, 'html.parser').find_all('time')[0]

# %%
print(test_time.get_text())
print(type(test_time.get_text()))
print(test_time.get_text().split(' '))
# Out:
# 2017-03-12 03:41
# <class 'str'>
# ['2017-03-12', '03:41']

# %%
# 测试成功，开始
for i in videos:
    aid = i['aid']
    url = spider3_url + aid
    v_d_t = BS(requests.get(url).content, 'html.parser').find('time').get_text().split(' ')
    i['date'] = v_d_t[0]
    i['time'] = v_d_t[1]
    i['url'] = url
videos[:2]
# Out:
# [{'aid': '9137695',
#   'coin': '461',
#   'comment': '881',
#   'date': '2017-03-13',
#   'favorites': '239',
#   'length': '64:48',
#   'play': '23795',
#   'review': '243',
#   'time': '11:17',
#   'title': '冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）',
#   'url': 'http://www.bilibili.com/video/av9137695',
#   'video_review': '881'},
#  {'aid': '9122374',
#   'coin': '199',
#   'comment': '512',
#   'date': '2017-03-13',
#   'favorites': '117',
#   'length': '92:58',
#   'play': '14183',
#   'review': '122',
#   'time': '10:57',
#   'title': '冰冷解说：“荒竹反击流”协同斗技首秀',
#   'url': 'http://www.bilibili.com/video/av9122374',
#   'video_review': '512'}]

# %%
# spider3成功
len(videos)
# Out:
# 146

# %% [markdown]
# ## 用Pandas制表

# %% [markdown]
# ### 制作与清理表格

# %%
# to DataFrame
df_videos = pd.DataFrame(videos)
df_videos.head()
# Out:
#        aid  coin comment        date favorites length   play review   time  \
# 0  9137695   461     881  2017-03-13       239  64:48  23795    243  11:17
# 1  9122374   199     512  2017-03-13       117  92:58  14183    122  10:57
# 2  9109711   681     822  2017-03-12       986  07:21  96186    743  03:41
# 3  9071355  3763    3027  2017-03-10       482  41:55  56359    846  14:21
# 4  9047855   295     605  2017-03-09       144  70:00  22233    149  02:12
#
#                           title                                      url  \
# 0   冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）  http://www.bilibili.com/video/av9137695
# 1            冰冷解说：“荒竹反击流”协同斗技首秀  http://www.bilibili.com/video/av9122374
# 2       【阴阳师】针女荒VS石踞/年兽+万年竹全传记！  http://www.bilibili.com/video/av9109711
# 3  【体验服快报】第005期：荒/万年竹/新版荒川/樱花妖等  http://www.bilibili.com/video/av9071355
# 4  冰冷解说：妇女节特辑！全女式神斗技实况（孟婆、烟烟罗等）  http://www.bilibili.com/video/av9047855
#
#   video_review
# 0          881
# 1          512
# 2          822
# 3         3027
# 4          605

# %%
# 改变 columns顺序
df_videos = df_videos[['aid','title', 'url', 'date','time','length', 'play', 'video_review', 'review', 'comment', 'favorites', 'coin']]
df_videos.head()
# Out:
#        aid                         title  \
# 0  9137695   冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）
# 1  9122374            冰冷解说：“荒竹反击流”协同斗技首秀
# 2  9109711       【阴阳师】针女荒VS石踞/年兽+万年竹全传记！
# 3  9071355  【体验服快报】第005期：荒/万年竹/新版荒川/樱花妖等
# 4  9047855  冰冷解说：妇女节特辑！全女式神斗技实况（孟婆、烟烟罗等）
#
#                                        url        date   time length   play  \
# 0  http://www.bilibili.com/video/av9137695  2017-03-13  11:17  64:48  23795
# 1  http://www.bilibili.com/video/av9122374  2017-03-13  10:57  92:58  14183
# 2  http://www.bilibili.com/video/av9109711  2017-03-12  03:41  07:21  96186
# 3  http://www.bilibili.com/video/av9071355  2017-03-10  14:21  41:55  56359
# 4  http://www.bilibili.com/video/av9047855  2017-03-09  02:12  70:00  22233
#
#   video_review review comment favorites  coin
# 0          881    243     881       239   461
# 1          512    122     512       117   199
# 2          822    743     822       986   681
# 3         3027    846    3027       482  3763
# 4          605    149     605       144   295

# %%
# 等下， review和 comment什么关系？
# 好吧.. video_review和 comment是一个东西，那 b站为什么把它们放到一个 api页面里
# rename 'video_review' to 'danmaku'
df_videos.rename(columns={'video_review':'danmaku'}, inplace=True)

# %%
# drop 'comment'
df_videos.drop('comment', axis=1, inplace=True)
df_videos.head()
# Out:
#        aid                         title  \
# 0  9137695   冰冷解说：“荒竹反击流”单人斗技实况（排名50-20）
# 1  9122374            冰冷解说：“荒竹反击流”协同斗技首秀
# 2  9109711       【阴阳师】针女荒VS石踞/年兽+万年竹全传记！
# 3  9071355  【体验服快报】第005期：荒/万年竹/新版荒川/樱花妖等
# 4  9047855  冰冷解说：妇女节特辑！全女式神斗技实况（孟婆、烟烟罗等）
#
#                                        url        date   time length   play  \
# 0  http://www.bilibili.com/video/av9137695  2017-03-13  11:17  64:48  23795
# 1  http://www.bilibili.com/video/av9122374  2017-03-13  10:57  92:58  14183
# 2  http://www.bilibili.com/video/av9109711  2017-03-12  03:41  07:21  96186
# 3  http://www.bilibili.com/video/av9071355  2017-03-10  14:21  41:55  56359
# 4  http://www.bilibili.com/video/av9047855  2017-03-09  02:12  70:00  22233
#
#   danmaku review favorites  coin
# 0     881    243       239   461
# 1     512    122       117   199
# 2     822    743       986   681
# 3    3027    846       482  3763
# 4     605    149       144   295

# %% [markdown]
# ### 导出表格

# %%
df_videos.to_csv('冰冷之海数据.csv')
