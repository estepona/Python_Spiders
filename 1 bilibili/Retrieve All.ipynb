# %%
import requests
from bs4 import BeautifulSoup as BS
import re
import codecs
import pandas as pd
from datetime import datetime

# %% [markdown]
# ## Define Functions

# %%
## get url_list
def get_url_list(mid):
    base_url = 'http://space.bilibili.com/ajax/member/getSubmitVideos?page='
    url_list = []
    no_page = int(re.findall('pages":(\d+)', str(requests.get('http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=%s' % mid).content))[-1])
    for i in range(1, no_page+1):
        url_list.append(base_url + '%d&mid=%s' % (i,mid))
    return url_list

## get info
def get_info(url_list):
    ## spider 1/3
    print('initiating spider 1/3...')
    videos = []
    index = 0
    total_videos = re.findall('count":(\d+)', str(requests.get('http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=%s' % mid).content))[-1]
    for url in url_list:
        url_page = codecs.decode(requests.get(url).content, 'unicode_escape')
        spider1_1 = re.findall('aid":(\d+).{1,50}title":"(.{1,80})","sub.{1,50}play":(\d+),"review":(\d+),"video_review":(\d+),"favorites":(\d+)', url_page)
        spider1_2 = re.findall('created":([\d:]+),.{1,120}length":"([\d:]+)', url_page)    
        spider1_2_index = 0 # index of spider1_2，reset every big loop
        for tuples in spider1_1:
            videos.append(dict())
            videos[index]['aid'] = tuples[0]
            videos[index]['title'] = tuples[1]
            videos[index]['play'] = tuples[2]
            videos[index]['review'] = tuples[3]
            videos[index]['danmaku'] = tuples[4]
            videos[index]['favorites'] = tuples[5]
            videos[index]['date'] = datetime.fromtimestamp( int(spider1_2[spider1_2_index][0]) ).strftime('%Y-%m-%d %H:%M:%S')[:10]
            videos[index]['time'] = datetime.fromtimestamp( int(spider1_2[spider1_2_index][0]) ).strftime('%Y-%m-%d %H:%M:%S')[11:]
            videos[index]['length'] = spider1_2[spider1_2_index][1]
            index += 1
            spider1_2_index += 1
            print(str(index) + '/' + total_videos + ' information collected from ' + url)
        print('page' + str(url_list.index(url) + 1) + 'completed')
    # clean 'title'
    for i in videos:
        i['title'] = i['title'].replace('\\/','/')
    print('spider 1/3 finished')
    ## spider 2/3
    print('initiating spider 2/3...')
    spider2_url = 'http://api.bilibili.com/archive_stat/stat?aid='
    for i in videos:
        aid = i['aid']
        url = spider2_url + aid # type(aid) = aid, thus no need to convert it
        coin = re.findall('coin":(\d+)', str(requests.get(url).content))[0]
        i['coin'] = coin
        print(str(videos.index(i)+1) + '/' + total_videos + ' information collected from ' + url) 
    print('spider 2/3 finished')
    ## spider 3/3
    print('initiating spider 3/3...')
    spider3_url = 'http://www.bilibili.com/video/av'
    for i in videos:
        aid = i['aid']
        url = spider3_url + aid
        i['url'] = url
        print(str(videos.index(i)+1) + '/' + total_videos + ' information collected from ' + url)
    print('spider 3/3 finished')
    ## finish
    return videos

## put into pandas
def into_pandas(videos):
    df_videos = pd.DataFrame(videos)
    # change columns order
    df_videos = df_videos[['aid','title', 'url', 'date','time','length', 'play', 'danmaku', 'review', 'favorites', 'coin']]
    # change object type to int
    df_videos['play'] = df_videos['play'].astype(int)
    df_videos['danmaku'] = df_videos['danmaku'].astype(int)
    df_videos['review'] = df_videos['review'].astype(int)
    df_videos['favorites'] = df_videos['favorites'].astype(int)
    df_videos['coin'] = df_videos['coin'].astype(int)
    print('Success putting data into Pandas')
    return df_videos

## export to csv file
# notice: to open it in excel, please open in notepad first, save it, and then open in excel
def export_csv(df):
    # get current time
    time = str(datetime.now())[:10] + '_' + str(datetime.now())[11:13] + '\'' + str(datetime.now())[14:16] + '\'' + str(datetime.now())[17:19]
    # export
    filename = 'stat_%s_%s.csv' % (mid, time)
    df.to_csv(filename, encoding='utf-8')

# %% [markdown]
# ## Run the cell below to manually input mids

# %%
### Run All

## get num of broadcasters
num = input("Enter the number of broadcasters to collect: ")
num = int(num)

## get a list of mid
mid_list = []
for i in range(num):
    mid = input("Enter {0}/{1} user's id: ".format(i, num))
    if mid.isdigit() == True and len(mid) <=9:
        print('User ID:', mid)
        mid = str(mid)
    else:
        mid = input("Last chance, please enter a valid ID: ")
        if mid.isdigit() == True and len(mid) <=9:
            print('User ID:', mid)
        else:
            print('Application Terminated. Please run again.')
            mid = 0

# %% [markdown]
# ## Define a mid_list and retrieve all.

# %%
mid_list = ['43536', '423895', '433351', '16693558', '3607081', '742470', '2745073', '883968']
mid_list
# Out:
# ['43536',
#  '423895',
#  '433351',
#  '16693558',
#  '3607081',
#  '742470',
#  '2745073',
#  '883968']

# %%
## call functions
for mid in mid_list:
    if mid != 0:
        # run all functions
        print('Application Running...')
        export_csv(into_pandas(get_info(get_url_list(mid))))
        print('\nA csv file containing information of all videos of the specified user id has been created in your current directory, please check!')
# Out:
# Application Running...
# initiating spider 1/3...
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:20: DeprecationWarning: invalid escape sequence '\/'
# 1/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 2/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 3/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 4/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 5/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 6/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 7/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 8/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 9/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 10/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 11/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 12/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 13/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 14/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 15/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 16/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 17/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 18/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 19/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# 20/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=1&mid=43536
# page1completed
# 21/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 22/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 23/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 24/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 25/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 26/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 27/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 28/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 29/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 30/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 31/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 32/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 33/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 34/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 35/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 36/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 37/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 38/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 39/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# 40/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=2&mid=43536
# page2completed
# 41/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 42/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 43/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 44/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 45/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 46/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 47/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 48/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 49/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 50/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 51/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 52/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 53/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 54/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 55/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 56/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 57/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 58/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 59/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# 60/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=3&mid=43536
# page3completed
# 61/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 62/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 63/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 64/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 65/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 66/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 67/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 68/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 69/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 70/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 71/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 72/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 73/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 74/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 75/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 76/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 77/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 78/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 79/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# 80/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=4&mid=43536
# page4completed
# 81/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 82/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 83/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 84/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 85/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 86/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 87/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 88/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 89/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 90/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 91/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 92/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 93/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 94/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 95/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 96/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 97/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 98/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 99/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# 100/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=5&mid=43536
# page5completed
# 101/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 102/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 103/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 104/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 105/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 106/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 107/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 108/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 109/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 110/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 111/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 112/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 113/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 114/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 115/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 116/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 117/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 118/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 119/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# 120/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=6&mid=43536
# page6completed
# 121/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 122/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 123/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 124/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 125/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 126/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 127/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 128/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 129/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 130/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 131/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 132/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 133/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 134/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 135/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 136/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 137/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 138/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# 139/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=7&mid=43536
# page7completed
# 140/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 141/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 142/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 143/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 144/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 145/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 146/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 147/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 148/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 149/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 150/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 151/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 152/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 153/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 154/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 155/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 156/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 157/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 158/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# 159/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=8&mid=43536
# page8completed
# 160/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 161/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 162/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 163/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 164/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 165/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 166/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 167/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 168/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 169/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 170/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 171/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 172/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 173/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 174/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 175/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 176/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 177/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 178/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# 179/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=9&mid=43536
# page9completed
# 180/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 181/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 182/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 183/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 184/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 185/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 186/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 187/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 188/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 189/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 190/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 191/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 192/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 193/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 194/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 195/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 196/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 197/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 198/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# 199/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=10&mid=43536
# page10completed
# 200/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=11&mid=43536
# 201/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=11&mid=43536
# 202/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=11&mid=43536
# 203/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=11&mid=43536
# 204/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=11&mid=43536
# 205/786 information collected from http://space.bilibili.com/ajax/member/getSubmitVideos?page=11&mid=43536
#
# 494/923 information collected from http://www.bilibili.com/video/av2549888
# 495/923 information collected from http://www.bilibili.com/video/av2539609
# 496/923 information collected from http://www.bilibili.com/video/av2539123
# 497/923 information collected from http://www.bilibili.com/video/av2538857
# 498/923 information collected from http://www.bilibili.com/video/av2535233
# 499/923 information collected from http://www.bilibili.com/video/av2524232
# 500/923 information collected from http://www.bilibili.com/video/av2519455
# 501/923 information collected from http://www.bilibili.com/video/av2519290
# 502/923 information collected from http://www.bilibili.com/video/av2519282
# 503/923 information collected from http://www.bilibili.com/video/av2516902
# 504/923 information collected from http://www.bilibili.com/video/av2508379
# 505/923 information collected from http://www.bilibili.com/video/av2505642
# 506/923 information collected from http://www.bilibili.com/video/av2486970
# 507/923 information collected from http://www.bilibili.com/video/av2486222
# 508/923 information collected from http://www.bilibili.com/video/av2483989
# 509/923 information collected from http://www.bilibili.com/video/av2475070
# 510/923 information collected from http://www.bilibili.com/video/av2474212
# 511/923 information collected from http://www.bilibili.com/video/av2459949
# 512/923 information collected from http://www.bilibili.com/video/av2457657
# 513/923 information collected from http://www.bilibili.com/video/av2457420
# 514/923 information collected from http://www.bilibili.com/video/av2455016
# 515/923 information collected from http://www.bilibili.com/video/av2446658
# 516/923 information collected from http://www.bilibili.com/video/av2442779
# 517/923 information collected from http://www.bilibili.com/video/av2429930
# 518/923 information collected from http://www.bilibili.com/video/av2429857
# 519/923 information collected from http://www.bilibili.com/video/av2429706
# 520/923 information collected from http://www.bilibili.com/video/av2427457
# 521/923 information collected from http://www.bilibili.com/video/av2422522
# 522/923 information collected from http://www.bilibili.com/video/av2420122
# 523/923 information collected from http://www.bilibili.com/video/av2418419
# 524/923 information collected from http://www.bilibili.com/video/av2416491
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     141             conn = connection.create_connection(
# --> 142                 (self.host, self.port), self.timeout, **extra_kw)
#     143
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      97     if err is not None:
# ---> 98         raise err
#      99
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      87                 sock.bind(source_address)
# ---> 88             sock.connect(sa)
#      89             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     362         else:
# --> 363             conn.request(method, url, **httplib_request_kw)
#     364
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# C:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# C:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     166     def connect(self):
# --> 167         conn = self._new_conn()
#     168         self._prepare_conn(conn)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     150             raise NewConnectionError(
# --> 151                 self, "Failed to establish a new connection: %s" % e)
#     152
#
# NewConnectionError: <requests.packages.urllib3.connection.HTTPConnection object at 0x00000212766C2898>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     639             retries = retries.increment(method, url, error=e, _pool=self,
# --> 640                                         _stacktrace=sys.exc_info()[2])
#     641             retries.sleep()
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     286         if new_retry.is_exhausted():
# --> 287             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     288
#
# MaxRetryError: HTTPConnectionPool(host='www.bilibili.com', port=80): Max retries exceeded with url: /video/av2401754 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x00000212766C2898>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-10-3e0a534574ed> in <module>()
#       4         # run all functions
#       5         print('Application Running...')
# ----> 6         export_csv(into_pandas(get_info(get_url_list(mid))))
#       7         print('\nA csv file containing information of all videos of the specified user id has been created in your current directory, please check!')
#
# <ipython-input-8-164d15f24b09> in get_info(url_list)
#      56         url = spider3_url + aid
#      57         try:
# ---> 58             v_d_t = BS(requests.get(url).content, 'html.parser').find('time').get_text().split(' ')
#      59             i['date'] = v_d_t[0]
#      60             i['time'] = v_d_t[1]
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     594
#     595         # Send the request
# --> 596         r = adapter.send(request, **kwargs)
#     597
#     598         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='www.bilibili.com', port=80): Max retries exceeded with url: /video/av2401754 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x00000212766C2898>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))

# %% [markdown]
# ## Mid Reference
# - 黑桐谷歌： 43536
# - 王老菊: 423895
# - 老E： 433351
# - Virgoo Team: 16693558
# - 球魂： 3607081
# - 冰冷之海：　742470
# - 氪金氪金克： 2745073
#
#
# - 暴漫： 883968
